# %% [markdown]
# # **[Individual Assignment] Developing Spelling Corrector for Bahasa Indonesia**
# - Pandya Athallah Erlambang
# - 19/444314/PA/*19376*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import re
from collections import Counter

def words(text): 
  return re.findall(r'\w+', text.lower())

Corpus = open('/content/drive/MyDrive/Colab Data/Spelling Corrector/ind_mixed_2012_300K/ind_mixed_2012_300K-sentences.txt').read()
WORDS = Counter(words(Corpora))

# %%
WORDS
# Out:
# Counter({'1': 4734,
#          'kening': 52,
#          'aie': 12,
#          'yang': 151796,
#          'terangkat': 86,
#          'naik': 1289,
#          'makin': 1140,
#          'tinggi': 3010,
#          '2': 4332,
#          'bagaimana': 3300,
#          'aktor': 150,
#          'aktris': 34,
#          'senior': 188,
#          'dan': 109411,
#          'punya': 3119,
#          'bakat': 137,
#          'akting': 24,
#          'luarbiasa': 19,
#          'bagus': 1001,
#          'itu': 51588,
#          'bisa': 18551,
#          'diyakinkan': 13,
#          'untuk': 42823,
#          'tampil': 413,
#          'superserius': 1,
#          'atas': 6491,
#          'skenario': 100,
#          'sesungguhnya': 833,
#          'tak': 12923,
#          'serius': 538,
#          '3': 3589,
#          'nah': 739,
#          'ingin': 4330,
#          'tahu': 4524,
#          'lebih': 13638,
#          'detil': 55,
#          'tentang': 6220,
#          'stadium': 41,
#          'aneka': 129,
#          'ragam': 122,
#          'istilah': 521,
#          'perawatan': 270,
#          'medis': 147,
#          'harus': 11777,
#          'dilalui': 97,
#          'oleh': 15295,
#          'penderita': 340,
#          'kanker': 234,
#          'payudara': 151,
#          '4': 2582,
#          'wiro': 76,
#          'hanya': 10789,
#          'menyengir': 3,
#          'geleng': 46,
#          'gelengkan': 24,
#          'kepala': 2473,
#          '5': 2734,
#          '15': 1073,
#          '19': 631,
#          'ibadah': 364,
#          'berisikan': 55,
#          'berbagai': 3302,
#          'bentuk': 1981,
#          'ritual': 154,
#          'merupakan': 5226,
#          'hal': 10628,
#          'sia': 413,
#          'apabila': 947,
#          'tidak': 43062,
#          'disertai': 257,
#          'hati': 3278,
#          'tulus': 145,
#          'bersih': 538,
#          'jujur': 497,
#          '6': 1736,
#          'jalanan': 270,
#          'lancar': 293,
#          'ini': 44693,
#          'kuharap': 12,
#          'adalah': 20331,
#          'pertanda': 119,
#          'bahwa': 15960,
#          'niatanku': 1,
#          'mulia': 165,
#          '7': 1567,
#          'saya': 21188,
#          'di': 70168,
#          'tuduh': 13,
#          'gerwani': 2,
#          'katanya': 1888,
#          'kepada': 9238,
#          'komparasi': 6,
#          'beberapa': 6972,
#          'waktu': 6438,
#          'lalu': 5872,
#          '8': 1309,
#          'suatu': 5308,
#          'kelembagaan': 68,
#          'pemantapan': 9,
#          'perilaku': 706,
#          'ways': 3,
#          'hidup': 5406,
#          'pada': 27579,
#          'kelompok': 2359,
#          'orang': 26627,
#          '9': 1175,
#          'belum': 5182,
#          'ada': 22138,
#          'penelitian': 1516,
#          'mendalam': 244,
#          'menghasilkan': 756,
#          'rekomendasi': 135,
#          'kebijakan': 1081,
#          'papar': 47,
#          'djati': 7,
#          '10': 1995,
#          'tapi': 10855,
#          'tentu': 2619,
#          'saja': 11063,
#          'harpa': 6,
#          'tetap': 3933,
#          'situ': 517,
#          'meski': 1316,
#          'pikirannya': 176,
#          'sudah': 15882,
#          'kembali': 5362,
#          'sejernih': 1,
#          'air': 3336,
#          '11': 1032,
#          'jelaslah': 58,
#          'artis': 185,
#          'tersebut': 10781,
#          'telah': 11070,
#          'keliru': 212,
#          'dalam': 39131,
#          'urusan': 554,
#          'diksi': 16,
#          'kata': 7662,
#          '12': 1138,
#          'padahal': 1708,
#          'kabareskim': 1,
#          'polri': 134,
#          'baru': 7018,
#          'komjen': 2,
#          'sutarman': 3,
#          'senin': 328,
#          'mengatakan': 3549,
#          'mengendus': 11,
#          'keberadaan': 571,
#          'tersangka': 176,
#          'kasus': 2007,
#          'dugaan': 264,
#          'korupsi': 710,
#          'dana': 1445,
#          'pembangunan': 1928,
#          'wisma': 60,
#          'atlet': 74,
#          'sea': 41,
#          'games': 57,
#          'palembang': 346,
#          '13': 726,
#          'pemimpin': 1340,
#          'redaksi': 119,
#          'suratkabar': 77,
#          'harian': 264,
#          'indonesia': 7117,
#          'raya': 500,
#          'pernah': 5238,
#          'dipenjara': 63,
#          'karena': 21065,
#          'karya': 1264,
#          'jurnalistiknya': 10,
#          '14': 749,
#          'pitak': 2,
#          'berpikir': 1392,
#          'sejenak': 332,
#          'kemudian': 6008,
#          'bertanya': 978,
#          'bila': 3391,
#          'kamu': 2987,
#          'sendiri': 7196,
#          'memilih': 1310,
#          'mana': 3008,
#          'akan': 27115,
#          'ambil': 410,
#          'kalo': 872,
#          'dicabutin': 1,
#          'terus': 3910,
#          'lama': 3281,
#          'ayah': 1418,
#          'botak': 67,
#          '16': 758,
#          'anak': 9765,
#          'pemakai': 109,
#          'komidi': 7,
#          'putarnya': 2,
#          'dipungut': 24,
#          'biaya': 1221,
#          'seribu': 163,
#          'rupiah': 466,
#          '17': 709,
#          'produk': 1401,
#          'dibuat': 896,
#          'smk': 78,
#          'bekerja': 2031,
#          'sama': 7251,
#          'dengan': 54857,
#          'industri': 831,
#          'menggunakan': 2731,
#          'merek': 242,
#          'bersama': 2970,
#          '18': 701,
#          'perahu': 281,
#          'cia': 187,
#          'soen': 70,
#          'dunia': 5001,
#          'ilmiah': 434,
#          'murni': 274,
#          'satu': 10288,
#          'satunya': 919,
#          'hukumnya': 99,
#          'ialah': 407,
#          'kebenaran': 1068,
#          '20': 1304,
#          'turis': 138,
#          'lain': 10116,
#          'juga': 18923,
#          'berkunjung': 290,
#          'ke': 21039,
#          'makassar': 906,
#          'jumlah': 1836,
#          'besar': 6476,
#          'antaranya': 447,
#          'inggris': 1059,
#          'italia': 186,
#          'singapura': 451,
#          'swiss': 88,
#          'kanada': 85,
#          'china': 347,
#          'rusia': 230,
#          'filipina': 141,
#          '21': 606,
#          'mengecewakan': 56,
#          'banyak': 9574,
#          '22': 563,
#          'maka': 7412,
#          'dari': 41478,
#          'diragukan': 125,
#          'tadi': 2060,
#          'syak': 12,
#          'seyogialah': 10,
#          'berpuasa': 97,
#          'meninggalkan': 1065,
#          'makan': 1725,
#          'sahur': 35,
#          '23': 487,
#          'tanpa': 3887,
#          'mekanisme': 302,
#          'seperti': 11829,
#          'kalaupun': 161,
#          'asam': 185,
#          'amino': 37,
#          'terbentuk': 232,
#          'ia': 18552,
#          'segera': 2889,
#          'hancur': 285,
#          '24': 595,
#          'sini': 1703,
#          'dewa': 640,
#          'wahai': 152,
#          'puteriku': 11,
#          '25': 665,
#          'djusman': 2,
#          'menganggap': 607,
#          'wc': 42,
#          'umum': 1877,
#          'terminal': 334,
#          'purabaya': 10,
#          'terharum': 2,
#          '26': 369,
#          'ketika': 6980,
#          'anda': 11556,
#          'menerima': 1901,
#          'inginkan': 228,
#          'merasakan': 855,
#          'perasaan': 1065,
#          'syukur': 187,
#          'menerimanya': 121,
#          'dapat': 14329,
#          'melepas': 264,
#          'mengganti': 203,
#          'gambar': 930,
#          '27': 392,
#          'minta': 1557,
#          'maaf': 654,
#          'kalau': 8400,
#          'berkenan': 93,
#          'keterbatasan': 159,
#          'menyampaikan': 550,
#          'pendapat': 892,
#          '28': 393,
#          'kami': 8038,
#          'mau': 5324,
#          'setia': 359,
#          'mu': 400,
#          'tuhan': 5571,
#          '29': 305,
#          'lelah': 205,
#          'kandang': 99,
#          'disebut': 1863,
#          'cage': 6,
#          'layer': 97,
#          'fatigue': 2,
#          'atau': 17455,
#          'osteoporosis': 22,
#          'sering': 2591,
#          'terjadi': 5563,
#          'ayam': 353,
#          'telur': 232,
#          'dipelihara': 47,
#          'baterai': 55,
#          '30': 991,
#          'berarti': 2524,
#          'perubahan': 1688,
#          'fisik': 805,
#          'kecil': 3156,
#          'menjadi': 14912,
#          'kurus': 82,
#          'gemuk': 129,
#          'pendek': 483,
#          'semakin': 3043,
#          'bukanlah': 836,
#          'proses': 3027,
#          'belajar': 2365,
#          'sebagai': 13722,
#          '31': 290,
#          'sebab': 2838,
#          'bagian': 3855,
#          'selatan': 958,
#          'makam': 166,
#          'berjarak': 99,
#          'meter': 647,
#          'areal': 105,
#          'persawahan': 33,
#          '32': 242,
#          'empat': 1234,
#          'obat': 800,
#          'kategori': 279,
#          'lini': 34,
#          'pertama': 3781,
#          'isoniazid': 2,
#          'rifampidin': 1,
#          'ethambutol': 1,
#          'pyrazinamid': 1,
#          '33': 197,
#          'kini': 2178,
#          'setelah': 6860,
#          'manfaat': 357,
#          'terapi': 271,
#          'urin': 44,
#          'gunawan': 131,
#          'takut': 1117,
#          'lagi': 8856,
#          'minum': 568,
#          'seni': 617,
#          '34': 153,
#          'ketahuilah': 54,
#          'sumber': 1788,
#          'penyebab': 420,
#          'penderitaan': 450,
#          '35': 263,
#          'apakah': 3299,
#          'saat': 10321,
#          'aku': 14370,
#          'masih': 8626,
#          'yahudi': 974,
#          '36': 189,
#          'nanti': 1769,
#          'gaji': 232,
#          'bs': 97,
#          'langsung': 3522,
#          'yayasan': 316,
#          '37': 133,
#          'bruce': 27,
#          'sebuah': 7384,
#          'stasiun': 413,
#          'tv': 404,
#          'australia': 294,
#          'kameramen': 5,
#          'reporter': 97,
#          'jakarta': 2514,
#          '38': 158,
#          'memang': 5781,
#          'mereka': 24021,
#          'menyangkal': 112,
#          'hak': 1454,
#          'datang': 3435,
#          '39': 133,
#          'merenungkan': 79,
#          'secara': 8453,
#          'khusuk': 10,
#          'peristiwa': 1061,
#          'rosario': 11,
#          'kita': 22363,
#          'mencontoh': 25,
#          'teladan': 108,
#          'maria': 372,
#          'mendengarkan': 549,
#          'sabda': 93,
#          'serta': 3773,
#          'menyimpannya': 27,
#          '40': 500,
#          'petugas': 518,
#          'loket': 40,
#          'mengizinkan': 118,
#          'boleh': 1518,
#          'jadi': 6274,
#          'mencoba': 1442,
#          'mengulang': 103,
#          'rintangan': 81,
#          'gerbang': 340,
#          'depan': 2965,
#          '41': 125,
#          'begitu': 4285,
#          'penjelasan': 438,
#          'syaikh': 126,
#          'ahmad': 382,
#          'kutanyakan': 11,
#          'ihwal': 37,
#          'cara': 3772,
#          'aneh': 703,
#          'mesir': 395,
#          'meredam': 46,
#          'amarah': 55,
#          '42': 136,
#          'alasan': 1274,
#          'baik': 7065,
#          'diklaim': 61,
#          'hubungan': 2169,
#          'individual': 143,
#          'antara': 4763,
#          'dokter': 1015,
#          'pasien': 786,
#          'terbaik': 758,
#          'mendapatkan': 2118,
#          'pengetahuan': 1400,
#          'kelangsungan': 96,
#          'optimal': 155,
#          'mencegah': 391,
#          'menyembuhkan': 126,
#          'penyakit': 951,
#          '43': 118,
#          'guardiola': 2,
#          'meminta': 1324,
#          'gagal': 634,
#          'mempertahankan': 468,
#          'gelar': 453,
#          'piala': 158,
#          'raja': 1489,
#          '44': 139,
#          'manakah': 82,
#          'namanya': 751,
#          'benar': 5061,
#          'tohukah': 2,
#          'toi': 3,
#          '45': 264,
#          'pengurus': 239,
#          'installers': 1,
#          'berhadapan': 251,
#          'bahkan': 4997,
#          'para': 9294,
#          'wireless': 108,
#          'lan': 165,
#          'mengalami': 1633,
#          'permasalahan': 430,
#          'multipath': 3,
#          '46': 116,
#          'sori': 9,
#          'nih': 200,
#          'ya': 2157,
#          'kata2': 55,
#          'berbau': 105,
#          'khayalan': 46,
#          'muhammad': 1333,
#          'mati': 1745,
#          'perpecahan': 77,
#          'masyakat': 3,
#          'muslim': 1492,
#          '47': 93,
#          'simanjuntak': 10,
#          'familia': 3,
#          'novita': 13,
#          '2006': 790,
#          'penerapan': 259,
#          'pertanian': 452,
#          'organik': 70,
#          'mengendalikan': 183,
#          'kualitas': 829,
#          'kesuburan': 21,
#          'tanah': 1848,
#          'pangan': 546,
#          'bebas': 908,
#          'pestisida': 12,
#          'studi': 809,
#          'bina': 88,
#          'sarana': 512,
#          'bhakti': 26,
#          'cisarua': 3,
#          'bogor': 242,
#          '48': 125,
#          'rusa': 28,
#          'palestina': 320,
#          'kadang': 1530,
#          'kala': 294,
#          'menemukan': 1708,
#          'batang': 460,
#          'sungai': 885,
#          'kering': 246,
#          'musim': 616,
#          'kemarau': 64,
#          '49': 106,
#          'namun': 7579,
#          'prosentase': 17,
#          'akidahnya': 10,
#          'jelek': 164,
#          'jumlahnya': 317,
#          'terlalu': 1743,
#          '50': 658,
#          'mungkin': 5063,
#          'mobil': 1533,
#          'diperbaiki': 117,
#          '51': 96,
#          'terutama': 1397,
#          'kabupaten': 889,
#          'dirancang': 175,
#          'program': 2140,
#          'bimbingan': 335,
#          'konseling': 229,
#          'busur': 49,
#          'menyarankan': 180,
#          'didefinisikan': 45,
#          'jelas': 2770,
#          'sehingga': 5119,
#          'sifat': 1026,
#          'integra': 3,
#          'pertahanan': 307,
#          'didukung': 323,
#          'partisipasi': 154,
#          'nyenyak': 43,
#          '52': 95,
#          'pun': 7108,
#          'makhluk': 665,
#          'allah': 6449,
#          'keberadaannya': 104,
#          'tergantung': 696,
#          'dia': 17568,
#          'akhirnya': 2999,
#          'pelayan': 139,
#          'maksud': 491,
#          'nya': 3388,
#          '53': 99,
#          'langkah': 1297,
#          'terdorong': 71,
#          'samping': 703,
#          'tubuhnya': 992,
#          'jatuh': 988,
#          'terbanting': 22,
#          '54': 69,
#          'apa': 9720,
#          'pertahankan': 22,
#          'jangan': 2098,
#          'ditambahkan': 100,
#          '55': 102,
#          'memiliki': 5858,
#          'ekor': 235,
#          'kuda': 412,
#          'betina': 110,
#          '56': 76,
#          'keluar': 2293,
#          'pintu': 1410,
#          'menuruni': 58,
#          'tangga': 657,
#          'semua': 7573,
#          'jalan': 4627,
#          'sebelah': 715,
#          'kanan': 589,
#          'duncan': 5,
#          '57': 66,
#          'podcast': 3,
#          'populer': 217,
#          'dikalangan': 25,
#          'internet': 738,
#          'marketer': 6,
#          '58': 81,
#          'dong': 937,
#          'yi': 456,
#          'bingung': 422,
#          'dilakukannya': 262,
#          'sekarang': 4690,
#          '59': 71,
#          'bayangkan': 231,
#          'negara': 5273,
#          'tetangga': 347,
#          'aja': 719,
#          'pakai': 434,
#          'perusahaan': 2563,
#          '60': 331,
#          'yesus': 3697,
#          'memaksudkan': 4,
#          'rohani': 385,
#          'kelimpahan': 22,
#          'maksudkan': 46,
#          '61': 43,
#          'kerapatan': 10,
#          'materinya': 21,
#          'tinggal': 1784,
#          'sepersepuluh': 12,
#          'kg': 143,
#          'tiap': 1073,
#          'liter': 85,
#          '62': 56,
#          'nasib': 348,
#          'qel': 18,
#          'pergi': 2262,
#          'pudu': 2,
#          '63': 75,
#          'gue': 922,
#          'berakhir': 428,
#          'hepatitis': 19,
#          'dasyat': 14,
#          'rumah': 5215,
#          'sakit': 1887,
#          '64': 71,
#          'keempat': 461,
#          'penyair': 187,
#          'terhitung': 118,
#          'paling': 3338,
#          'menampilkan': 276,
#          'sajak': 240,
#          'jernih': 127,
#          'jauh': 2460,
#          'hiruk': 42,
#          'pikuk': 36,
#          'sosial': 1669,
#          'politik': 2269,
#          '65': 103,
#          'prioritas': 217,
#          'penting': 2601,
#          'kemandirian': 102,
#          'energi': 818,
#          'pemerataan': 45,
#          'jaminan': 351,
#          'ketersediaan': 117,
#          'listrik': 782,
#          'bagi': 6637,
#          'rakyat': 1755,
#          'harga': 1561,
#          'terjangkau': 96,
#          '66': 48,
#          'kematian': 785,
#          'akrab': 280,
#          'demikianlah': 266,
#          'pikir': 501,
#          'manusia': 6015,
#          'kelangkaan': 29,
#          'pengendalian': 146,
#          'hanyalah': 561,
#          'peradaban': 371,
#          'lupa': 739,
#          'bukan': 6044,
#          'menyadari': 824,
#          'potensi': 639,
#          'impotensi': 6,
#          'diri': 5440,
#          '67': 46,
#          'keren': 82,
#          'lho': 203,
#          'ika': 52,
#          'suara': 2546,
#          'amat': 698,
#          'manja': 61,
#          '68': 45,
#          'polisi': 780,
#          'berkumis': 27,
#          'mendengar': 1632,
#          'feli': 12,
#          'berhenti': 840,
#          'menari': 118,
#          'seolah': 667,
#          'menolaknya': 59,
#          '69': 62,
#          'terima': 881,
#          'kasih': 1613,
#          'hikmat': 155,
#          'kau': 3407,
#          'berikan': 366,
#          'dipakai': 771,
#          'kawan': 495,
#          'sekerja': 17,
#          'membimbing': 106,
#          'bertemu': 1125,
#          'mengenal': 796,
#          'pribadi': 1348,
#          '70': 275,
#          'dimaklumi': 30,
#          'sebagian': 2287,
#          'anggotanya': 135,
#          'pegawai': 315,
#          'negeri': 1953,
#          'lapisan': 207,
#          'ningrat': 17,
#          '71': 48,
#          'tua': 2035,
#          'menyukai': 284,
#          'peran': 876,
#          '72': 51,
#          'berhari': 31,
#          'hari': 6481,
#          'memburu': 58,
#          'berita': 941,
#          'berhasil': 1922,
#          'memperoleh': 941,
#          'kabar': 623,
#          '73': 48,
#          'complain': 1,
#          'digeret': 1,
#          'sana': 1689,
#          'yanty': 20,
#          'pasar': 1997,
#          '74': 40,
#          'yen': 81,
#          'menguat': 78,
#          '93': 28,
#          '83': 37,
#          'per': 1036,
#          'dolar': 310,
#          '94': 37,
#          '75': 142,
#          'contoh': 1077,
#          'misalkan': 112,
#          'jeruk': 82,
#          'bali': 397,
#          'buah': 860,
#          'asli': 429,
#          'asal': 833,
#          'terbukti': 379,
#          'menurunkan': 308,
#          'kolesterol': 32,
#          'jantung': 405,
#          'dilakukan': 4318,
#          'israel': 703,
#          '76': 52,
#          'menu': 191,
#          'favorit': 98,
#          'pengunjung': 316,
#          '77': 33,
#          'tetapi': 7326,
#          'konsep': 845,
#          'keseluruhan': 413,
#          'membuat': 5171,
#          'garis': 636,
#          'keseharian': 47,
#          'menihilkan': 3,
#          'kemungkinan': 1034,
#          'selalu': 3543,
#          'kebahagiaan': 331,
#          'kepingnya': 2,
#          '78': 41,
#          'tergerak': 33,
#          'belas': 313,
#          'kasihan': 186,
#          'bunda': 64,
#          'teresa': 11,
#          'rekan': 419,
#          'barunya': 95,
#          'itupun': 257,
#          'menyewa': 108,
#          'ruangan': 723,
#          'merawat': 125,
#          'sekarat': 34,
#          '79': 39,
#          'eton': 3,
#          'pula': 2834,
#          'bahagia': 551,
#          'nasibnya': 50,
#          '80': 259,
#          'biar': 354,
#          'keadaannya': 101,
#          'parah': 320,
#          'lukanya': 38,
#          'berat': 1066,
#          'sekali': 4436,
#          'ki': 1157,
#          'ageng': 47,
#          'palandongan': 12,
#          'mendesak': 271,
#          'dua': 5595,
#          'agar': 4599,
#          'bersi': 3,
#          'cepat': 2176,
#          'membawanya': 140,
#          'sampai': 6959,
#          'lumajang': 8,
#          '81': 41,
#          'sayangnya': 337,
#          'kebanyakan': 643,
#          'sastrawan': 72,
#          'terjebak': 141,
#          'melukiskan': 74,
#          'sebatas': 139,
#          'dipercaya': 279,
#          'suntuk': 19,
#          'memecahkan': 153,
#          'segala': 2238,
#          'masalah': 3138,
#          '82': 51,
#          'asyik': 228,
#          'sambil': 2923,
#          'tersenyum': 748,
#          'jerman': 453,
#          'william': 181,
#          'tyndale': 24,
#          'tokoh': 1238,
#          'lainnya': 3195,
#          'melepaskan': 484,
#          'eksekusi': 111,
#          '84': 39,
#          'komunikasi': 775,
#          'massa': 588,
#          'saluran': 311,
#          'utama': 1525,
#          'surat': 1461,
#          'film': 1485,
#          'radio': 411,
#          'televisi': 562,
#          '85': 75,
#          'padam': 64,
#          'dicegah': 46,
#          '86': 35,
#          'malem': 31,
#          'selesainya': 20,
#          'sekitar': 2929,
#          'jam': 1872,
#          'gw': 486,
#          'sempat': 1273,
#          'meditasi': 111,
#          'abis': 96,
#          'setengah': 701,
#          '87': 32,
#          'partai': 1471,
#          'mendudukkan': 15,
#          'kadernya': 11,
#          'dpr': 596,
#          'sejumlah': 1408,
#          'menteri': 857,
#          'pejabat': 560,
#          'daerah': 3425,
#          '88': 51,
#          'kesepakatan': 270,
#          'global': 511,
#          'khususnya': 747,
#          'berkaitan': 512,
#          'promosi': 266,
#          'kesehatan': 1097,
#          'peningkatan': 653,
#          'sehat': 708,
#          'perlu': 3240,
#          'dikaji': 49,
#          'direview': 5,
#          'ditindak': 22,
#          'lanjuti': 11,
#          '89': 32,
#          'heechul': 77,
#          'selesai': 1181,
#          'denga': 32,
#          'kegiatannya': 64,
#          'menatap': 373,
#          'maeli': 2,
#          'lurus': 203,
#          '90': 184,
#          'suka': 1349,
#          'dadah': 3,
#          'soeharto': 445,
#          'mantan': 517,
#          'presiden': 1552,
#          '91': 24,
#          'disini': 559,
#          'khawatir': 425,
#          'pemburu': 77,
#          'hiranyaka': 8,
#          'seorang': 7866,
#          'tertangkap': 131,
#          'perangkap': 34,
#          'baiknya': 259,
#          'nitisastras': 2,
#          '92': 35,
#          'masyarakat': 4989,
#          'riau': 210,
#          'berbangga': 19,
#          'memproduksi': 201,
#          'beras': 255,
#          'anggaran': 639,
#          'sebesar': 1070,
#          'digunakan': 1901,
#          'membangun': 1349,
#          'unit': 786,
#          'kamar': 1157,
#          'hotel': 873,
#          'berlokasi': 67,
#          'tanjung': 118,
#          'tarabitan': 1,
#          'minahasa': 18,
#          'utara': 715,
#          'diharapkan': 834,
#          'rampung': 131,
#          'tahun': 9685,
#          '2013': 39,
#          'pencipta': 154,
#          'melanjutkan': 588,
#          'memelihara': 209,
#          'kehidupan': 2628,
#          'kis': 84,
#          '95': 82,
#          'mendjadi': 33,
#          'tanggung': 643,
#          'djawab': 1,
#          'jang': 477,
#          'besarlah': 8,
#          'membasmi': 27,
#          'anasir': 15,
#          'laki': 1838,
#          'maupun': 2734,
#          'perempuan': 1592,
#          'menjimpan': 1,
#          'rahasia': 611,
#          '96': 35,
#          'pendirian': 164,
#          'patung': 199,
#          'obama': 72,
#          'taman': 536,
#          'menteng': 14,
#          'pusat': 1546,
#          'dinilai': 360,
#          'dilihat': 703,
#          'pertimbangan': 359,
#          'maknanya': 82,
#          '97': 37,
#          'oralit': 4,
#          'dijual': 270,
#          'beragam': 339,
#          'kemasan': 89,
#          'diberi': 788,
#          'macam': 1604,
#          'rasa': 2384,
#          '98': 44,
#          'bunga': 682,
#          'cactus': 2,
#          'mengarah': 250,
#          'sidequest': 5,
#          'menyelesaikan': 552,
#          'tahap': 753,
#          'awal': 1717,
#          'permainan': 461,
#          'meletakkannya': 28,
#          'ditahan': 131,
#          'sementara': 3092,
#          '99': 79,
#          'luar': 3013,
#          'meneruskan': 216,
#          'kerjakan': 126,
#          'menyempurnakan': 59,
#          'membelokkan': 18,
#          'arah': 1484,
#          'pikirkan': 129,
#          'sebelumnya': 2045,
#          '100': 678,
#          'muncul': 1726,
#          'kuburan': 144,
#          'massal': 150,
#          'digali': 45,
#          'dibunuh': 242,
#          '101': 25,
#          'aphid': 3,
#          'selama': 4087,
#          'panas': 682,
#          'lalat': 48,
#          'tertentu': 1423,
#          'tsese': 1,
#          'afrika': 256,
#          'tipe': 397,
#          '102': 18,
#          'sambar': 7,
#          'adi': 175,
#          'pattrick': 31,
#          '103': 27,
#          'sehari': 702,
#          'kondisi': 1981,
#          'waras': 39,
#          'justru': 1611,
#          'memburuk': 52,
#          ...})

# %% [markdown]
# ## **Probability Theory**

# %% [markdown]
# The call correction(w) tries to choose the most likely spelling correction for w. There is no way to know for sure (for example, should "lates" be corrected to "late" or "latest" or "lattes" or ...?), which suggests we use probabilities. We are trying to find the correction c, out of all possible candidate corrections, that maximizes the probability that c is the intended correction, given the original word w:
# > argmax c∈ candidates P(c|w)
#
# By Bayes' Theorem this is equivalent to:
# > argmax c∈ candidates P(c) P(w|c) / P(w)
#
# Since P(w) is the same for every possible candidate c, we can factor it out, giving:
# > argmax c∈ candidates P(c) P(w|c)
#
# The four parts of this expression are:
# 1. **Selection Mechanism**: argmax
# We choose the candidate with the highest combined probability.
#
# 2. **Candidate Model**: c∈ candidates
# This tells us which candidate corrections, c, to consider.
#
# 3. **Language Model**: P(c)
# The probability that c appears as a word of English text. For example, occurrences of "the" make up about 7% of English text, so we should have P(the) = 0.07.
#
# 4. **Error Model**: P(w|c)
# The probability that w would be typed in a text when the author meant c. For example, P(teh|the) is relatively high, but P(theeexyz|the) would be very low.
#
# One obvious question is: why take a simple expression like P(c|w) and replace it with a more complex expression involving two models rather than one? The answer is that P(c|w) is already conflating two factors, and it is easier to separate the two out and deal with them explicitly. Consider the misspelled word w="thew" and the two candidate corrections c="the" and c="thaw". Which has a higher P(c|w)? Well, "thaw" seems good because the only change is "a" to "e", which is a small change. On the other hand, "the" seems good because "the" is a very common word, and while adding a "w" seems like a larger, less probable change, perhaps the typist's finger slipped off the "e". The point is that to estimate P(c|w) we have to consider both the probability of c and the probability of the change from c to w anyway, so it is cleaner to formally separate the two factors.

# %% [markdown]
# ## **Building the Language Model**

# %% [markdown]
# 1. **Selection Mechanism**: In Python, max with a key argument does 'argmax'.

# %% [markdown]
# 2. **Candidate Model**: First a new concept: a **simple edit** to a word is a deletion (remove one letter), a transposition (swap two adjacent letters), a replacement (change one letter to another) or an insertion (add a letter). The function edits1 returns a set of all the edited strings (whether words or not) that can be made with one simple edit:

# %%
def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

# %% [markdown]
# This can be a big set. For a word of length n, there will be n deletions, n-1 transpositions, 26n alterations, and 26(n+1) insertions, for a total of 54n+25 (of which a few are typically duplicates). For example,

# %%
len(edits1('analsis'))
# Out:
# 390

# %% [markdown]
# However, if we restrict ourselves to words that are known—that is, in the dictionary— then the set is much smaller:

# %%
def known(words): 
  return set(w for w in words if w in WORDS)

# %%
known(edits1('analsis'))
# Out:
# {'analis', 'analisis', 'analsis', 'analysis'}

# %% [markdown]
# We'll also consider corrections that require two simple edits. This generates a much bigger set of possibilities, but usually only a few of them are known words:

# %%
def edits2(word): 
  return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
len(set(edits2('analisis')))
# Out:
# 90741

# %%
known(edits2('analisis'))
# Out:
# {'analiais',
#  'analis',
#  'analisa',
#  'analisis',
#  'analisisi',
#  'analitik',
#  'analitis',
#  'analogis',
#  'analsis',
#  'analysis',
#  'dianalisis',
#  'paralisis'}

# %%
known(edits2('analsis'))
# Out:
# {'analaisa',
#  'analiais',
#  'analis',
#  'analisa',
#  'analisis',
#  'analisisi',
#  'analitis',
#  'analogis',
#  'analsis',
#  'analysis',
#  'anarkis',
#  'anasir',
#  'canalis',
#  'kanalis',
#  'narsis',
#  'onasis'}

# %% [markdown]
# We say that the results of edits2(w) have an edit distance of 2 from w.

# %% [markdown]
# 3. **Language Model**: We can estimate the probability of a word, P(word), by counting the number of times each word appears in a text file. The function words breaks text into words, then the variable WORDS holds a Counter of how often each word appears, and P estimates the probability of each word, based on this Counter:

# %% [markdown]
# 3.1 **Unigram Model**

# %% [markdown]
# The unigram language model states that the probability of a sentence is determined by the product of the probability of each constituent word in the
# document.
#
# - **P(w1w2...wn) = P(w1) x P(w2) x .... P(wn)**, where n is the number of constituent words in the sentence.
# - P_uni is a function for computing the probability of each word in the document.

# %%
# Unigram model
def P_uni(word, N=sum(WORDS.values())): 
  return WORDS[word] / N

# %% [markdown]
# 3.2 **Bigram Model**

# %% [markdown]
# The bigram language model follows the Markov's assumption, in which, the probability of a word depends only on the previous word.
#
# - **P(wi|w1w2...w(i-1)) = P(wi|w(i-1))**, where i is the ith word in a sentence.
# - freq is a function for finding the number of occurences of each possible consecutive word pairs in the document. This is required for calculating the conditional probability as the model is inspired from the Bayes Theorem
# - P_bi is a similar function to P_uni, but it follows the bigram formula

# %%
def freq(input_string):
  freq = {}
  words = input_string.split()
  if len(words) == 1:
    return freq
  for idx, word in enumerate(words):
    if idx+1 < len(words):
      word_pair = (word, words[idx+1])
      if word_pair in freq:
        freq[word_pair] += 1
      else:
        freq[word_pair] = 1
  return freq

COUNT_PAIRS = freq(Corpus)
COUNT_PAIRS
# Out:
# {('1', '”Kening'): 1,
#  ('”Kening', 'Aie'): 1,
#  ('Aie', 'yang'): 2,
#  ('yang', 'terangkat'): 4,
#  ('terangkat', 'naik'): 1,
#  ('naik', 'makin'): 1,
#  ('makin', 'tinggi.'): 4,
#  ('tinggi.', '2'): 1,
#  ('2', 'Bagaimana'): 1,
#  ('Bagaimana', 'aktor-aktris'): 1,
#  ('aktor-aktris', 'senior'): 1,
#  ('senior', 'dan'): 6,
#  ('dan', 'yang'): 611,
#  ('yang', 'punya'): 238,
#  ('punya', 'bakat'): 10,
#  ('bakat', 'akting'): 1,
#  ('akting', 'luarbiasa'): 1,
#  ('luarbiasa', 'bagus'): 1,
#  ('bagus', 'itu'): 7,
#  ('itu', 'bisa'): 401,
#  ('bisa', 'diyakinkan'): 4,
#  ('diyakinkan', 'untuk'): 2,
#  ('untuk', 'tampil'): 28,
#  ('tampil', 'superserius'): 1,
#  ('superserius', 'atas'): 1,
#  ('atas', 'skenario'): 1,
#  ('skenario', 'yang'): 10,
#  ('yang', 'sesungguhnya'): 100,
#  ('sesungguhnya', 'tak'): 9,
#  ('tak', 'serius?'): 1,
#  ('serius?', '3'): 1,
#  ('3', 'Nah,'): 1,
#  ('Nah,', 'ingin'): 3,
#  ('ingin', 'tahu'): 108,
#  ('tahu', 'lebih'): 24,
#  ('lebih', 'detil'): 4,
#  ('detil', 'tentang'): 6,
#  ('tentang', 'stadium'): 1,
#  ('stadium', 'dan'): 2,
#  ('dan', 'aneka'): 15,
#  ('aneka', 'ragam'): 4,
#  ('ragam', 'istilah'): 1,
#  ('istilah', 'perawatan'): 1,
#  ('perawatan', 'medis'): 5,
#  ('medis', 'yang'): 22,
#  ('yang', 'harus'): 1467,
#  ('harus', 'dilalui'): 12,
#  ('dilalui', 'oleh'): 14,
#  ('oleh', 'penderita'): 4,
#  ('penderita', 'kanker'): 8,
#  ('kanker', 'payudara?'): 1,
#  ('payudara?', '4'): 1,
#  ('4', 'Wiro'): 1,
#  ('Wiro', 'hanya'): 3,
#  ('hanya', 'bisa'): 412,
#  ('bisa', 'menyengir'): 1,
#  ('menyengir', 'dan'): 1,
#  ('dan', 'geleng-gelengkan'): 1,
#  ('geleng-gelengkan', 'kepala.'): 2,
#  ('kepala.', '5'): 1,
#  ('5', '15:19)'): 1,
#  ('15:19)', 'Ibadah'): 1,
#  ('Ibadah', 'yang'): 2,
#  ('yang', 'berisikan'): 25,
#  ('berisikan', 'berbagai'): 1,
#  ('berbagai', 'bentuk'): 46,
#  ('bentuk', 'ritual'): 1,
#  ('ritual', 'merupakan'): 1,
#  ('merupakan', 'hal'): 110,
#  ('hal', 'yang'): 1494,
#  ('yang', 'sia-sia'): 15,
#  ('sia-sia', 'apabila'): 1,
#  ('apabila', 'tidak'): 23,
#  ('tidak', 'disertai'): 12,
#  ('disertai', 'oleh'): 14,
#  ('oleh', 'hati'): 5,
#  ('hati', 'yang'): 154,
#  ('yang', 'tulus,'): 6,
#  ('tulus,', 'bersih,'): 1,
#  ('bersih,', 'dan'): 9,
#  ('dan', 'jujur.'): 14,
#  ('jujur.', '6'): 1,
#  ('6', 'Jalanan'): 1,
#  ('Jalanan', 'yang'): 2,
#  ('yang', 'lancar'): 5,
#  ('lancar', 'ini'): 1,
#  ('ini', 'kuharap'): 1,
#  ('kuharap', 'adalah'): 1,
#  ('adalah', 'pertanda'): 4,
#  ('pertanda', 'bahwa'): 17,
#  ('bahwa', 'niatanku'): 1,
#  ('niatanku', 'mulia.'): 1,
#  ('mulia.', '7'): 1,
#  ('7', '“saya'): 1,
#  ('“saya', 'di'): 1,
#  ('di', 'tuduh'): 2,
#  ('tuduh', 'Gerwani”'): 1,
#  ('Gerwani”', 'katanya'): 1,
#  ('katanya', 'kepada'): 12,
#  ('kepada', 'Komparasi'): 1,
#  ('Komparasi', 'beberapa'): 1,
#  ('beberapa', 'waktu'): 182,
#  ('waktu', 'yang'): 590,
#  ('yang', 'lalu.'): 134,
#  ('lalu.', '8'): 1,
#  ('8', 'Suatu'): 1,
#  ('Suatu', 'kelembagaan'): 1,
#  ('kelembagaan', 'adalah'): 1,
#  ('adalah', 'suatu'): 295,
#  ('suatu', 'pemantapan'): 1,
#  ('pemantapan', 'perilaku'): 1,
#  ('perilaku', '(ways)'): 1,
#  ('(ways)', 'yang'): 1,
#  ('yang', 'hidup'): 225,
#  ('hidup', 'pada'): 40,
#  ('pada', 'suatu'): 226,
#  ('suatu', 'kelompok'): 33,
#  ('kelompok', 'orang.'): 2,
#  ('orang.', '9'): 1,
#  ('9', 'Belum'): 1,
#  ('Belum', 'ada'): 20,
#  ('ada', 'penelitian'): 9,
#  ('penelitian', 'yang'): 124,
#  ('yang', 'mendalam'): 48,
#  ('mendalam', 'dan'): 18,
#  ('dan', 'menghasilkan'): 30,
#  ('menghasilkan', 'rekomendasi'): 2,
#  ('rekomendasi', 'kebijakan,”'): 1,
#  ('kebijakan,”', 'papar'): 1,
#  ('papar', 'Djati.'): 1,
#  ('Djati.', '10'): 1,
#  ('10', 'Tapi'): 1,
#  ('Tapi', 'tentu'): 13,
#  ('tentu', 'saja'): 477,
#  ('saja', 'harpa'): 1,
#  ('harpa', 'itu'): 3,
#  ('itu', 'tetap'): 97,
#  ('tetap', 'ada'): 51,
#  ('ada', 'di'): 1764,
#  ('di', 'situ'): 133,
#  ('situ', 'meski'): 1,
#  ('meski', 'pikirannya'): 1,
#  ('pikirannya', 'sudah'): 3,
#  ('sudah', 'kembali'): 33,
#  ('kembali', 'sejernih'): 1,
#  ('sejernih', 'air.'): 1,
#  ('air.', '11'): 1,
#  ('11', 'Jelaslah,'): 1,
#  ('Jelaslah,', 'aktor'): 1,
#  ('aktor', 'dan'): 6,
#  ('dan', 'artis'): 3,
#  ('artis', 'tersebut'): 2,
#  ('tersebut', 'telah'): 94,
#  ('telah', 'keliru'): 3,
#  ('keliru', 'dalam'): 8,
#  ('dalam', 'urusan'): 39,
#  ('urusan', 'diksi'): 1,
#  ('diksi', 'kata.'): 1,
#  ('kata.', '12'): 1,
#  ('12', 'Padahal,'): 1,
#  ('Padahal,', 'Kabareskim'): 1,
#  ('Kabareskim', 'Polri'): 1,
#  ('Polri', 'yang'): 11,
#  ('yang', 'baru'): 739,
#  ('baru', 'Komjen'): 1,
#  ('Komjen', 'Sutarman'): 1,
#  ('Sutarman', 'pada'): 1,
#  ('pada', 'Senin'): 17,
#  ('Senin', '(11/7)'): 1,
#  ('(11/7)', 'lalu'): 1,
#  ('lalu', 'mengatakan'): 10,
#  ('mengatakan', 'telah'): 3,
#  ('telah', 'mengendus'): 1,
#  ('mengendus', 'keberadaan'): 1,
#  ('keberadaan', 'tersangka'): 2,
#  ('tersangka', 'kasus'): 17,
#  ('kasus', 'dugaan'): 23,
#  ('dugaan', 'korupsi'): 21,
#  ('korupsi', 'dana'): 9,
#  ('dana', 'pembangunan'): 9,
#  ('pembangunan', 'Wisma'): 2,
#  ('Wisma', 'Atlet'): 9,
#  ('Atlet', 'SEA'): 5,
#  ('SEA', 'Games'): 18,
#  ('Games', 'di'): 5,
#  ('di', 'Palembang'): 28,
#  ('Palembang', 'itu.'): 3,
#  ('itu.', '13'): 1,
#  ('13', 'Pemimpin'): 1,
#  ('Pemimpin', 'Redaksi'): 12,
#  ('Redaksi', 'Suratkabar'): 2,
#  ('Suratkabar', 'Harian'): 1,
#  ('Harian', 'Indonesia'): 3,
#  ('Indonesia', 'Raya'): 13,
#  ('Raya', 'ini'): 6,
#  ('ini', 'pernah'): 39,
#  ('pernah', 'dipenjara'): 3,
#  ('dipenjara', 'karena'): 6,
#  ('karena', 'karya-karya'): 1,
#  ('karya-karya', 'jurnalistiknya.'): 1,
#  ('jurnalistiknya.', '14'): 1,
#  ('14', "'"): 1,
#  ("'", 'Pitak'): 1,
#  ('Pitak', 'berpikir'): 1,
#  ('berpikir', 'sejenak,'): 9,
#  ('sejenak,', 'kemudian'): 7,
#  ('kemudian', 'bertanya:'): 1,
#  ('bertanya:', "'Bila"): 1,
#  ("'Bila", 'kamu'): 1,
#  ('kamu', 'sendiri'): 7,
#  ('sendiri', 'yang'): 252,
#  ('yang', 'memilih,'): 3,
#  ('memilih,', 'yang'): 1,
#  ('yang', 'mana'): 151,
#  ('mana', 'yang'): 238,
#  ('yang', 'akan'): 2514,
#  ('akan', 'kamu'): 17,
#  ('kamu', 'ambil?'): 1,
#  ('ambil?', '15'): 1,
#  ('15', '“Kalo'): 1,
#  ('“Kalo', 'dicabutin'): 1,
#  ('dicabutin', 'terus'): 1,
#  ('terus', 'lama-lama'): 1,
#  ('lama-lama', 'kepala'): 1,
#  ('kepala', 'Ayah'): 1,
#  ('Ayah', 'bisa'): 3,
#  ('bisa', 'botak.'): 1,
#  ('botak.', '16'): 1,
#  ('16', 'Anak-anak'): 1,
#  ('Anak-anak', 'pemakai'): 1,
#  ('pemakai', 'komidi'): 1,
#  ('komidi', 'putarnya'): 1,
#  ('putarnya', 'hanya'): 1,
#  ('hanya', 'dipungut'): 1,
#  ('dipungut', 'biaya'): 7,
#  ('biaya', 'seribu'): 1,
#  ('seribu', 'rupiah.'): 2,
#  ('rupiah.', '17'): 1,
#  ('17', 'Produk'): 1,
#  ('Produk', 'yang'): 11,
#  ('yang', 'dibuat'): 217,
#  ('dibuat', 'oleh'): 88,
#  ('oleh', 'SMK'): 3,
#  ('SMK', 'dan'): 4,
#  ('dan', 'bekerja'): 64,
#  ('bekerja', 'sama'): 172,
#  ('sama', 'dengan'): 736,
#  ('dengan', 'industri'): 7,
#  ('industri', 'itu'): 3,
#  ('itu', 'menggunakan'): 13,
#  ('menggunakan', 'merek'): 4,
#  ('merek', 'bersama,'): 1,
#  ('bersama,', 'SMK'): 1,
#  ('dan', 'industri.'): 11,
#  ('industri.', '18'): 1,
#  ('18', 'Perahu'): 1,
#  ('Perahu', 'itu'): 2,
#  ('itu', 'adalah'): 1129,
#  ('adalah', 'perahu'): 2,
#  ('perahu', 'Cia'): 1,
#  ('Cia', 'Soen.'): 11,
#  ('Soen.', '19'): 1,
#  ('19', 'Dalam'): 1,
#  ('Dalam', 'dunia'): 42,
#  ('dunia', 'ilmiah'): 1,
#  ('ilmiah', 'murni,'): 1,
#  ('murni,', 'satu-satunya'): 1,
#  ('satu-satunya', 'hukumnya'): 1,
#  ('hukumnya', 'ialah'): 1,
#  ('ialah', 'kebenaran.'): 1,
#  ('kebenaran.', '20'): 1,
#  ('20', 'Turis'): 1,
#  ('Turis', 'lain'): 1,
#  ('lain', 'yang'): 982,
#  ('yang', 'juga'): 741,
#  ('juga', 'berkunjung'): 3,
#  ('berkunjung', 'ke'): 194,
#  ('ke', 'Makassar'): 20,
#  ('Makassar', 'dalam'): 4,
#  ('dalam', 'jumlah'): 147,
#  ('jumlah', 'besar'): 26,
#  ('besar', 'di'): 224,
#  ('di', 'antaranya'): 301,
#  ('antaranya', 'Inggris,'): 1,
#  ('Inggris,', 'Italia,'): 1,
#  ('Italia,', 'Singapura,'): 1,
#  ('Singapura,', 'Swiss,'): 1,
#  ('Swiss,', 'Kanada,'): 1,
#  ('Kanada,', 'China,'): 1,
#  ('China,', 'Rusia,'): 1,
#  ('Rusia,', 'Filipina,'): 1,
#  ('Filipina,', 'dan'): 5,
#  ('dan', 'Swiss.'): 2,
#  ('Swiss.', '21'): 1,
#  ('21', 'Bisa'): 1,
#  ('Bisa', 'mengecewakan'): 1,
#  ('mengecewakan', 'banyak'): 1,
#  ('banyak', 'orang.'): 74,
#  ('orang.', '22'): 1,
#  ('22', 'Maka'): 2,
#  ('Maka', 'dari'): 31,
#  ('dari', 'waktu'): 70,
#  ('yang', 'diragukan'): 4,
#  ('diragukan', 'tadi'): 1,
#  ('tadi', '(waktu'): 1,
#  ('(waktu', 'syak),'): 1,
#  ('syak),', 'seyogialah'): 1,
#  ('seyogialah', 'orang'): 1,
#  ('orang', 'yang'): 3540,
#  ('yang', 'berpuasa,'): 1,
#  ('berpuasa,', 'meninggalkan'): 1,
#  ('meninggalkan', 'makan'): 1,
#  ('makan', 'sahur.'): 1,
#  ('sahur.', '23'): 1,
#  ('23', 'Tanpa'): 1,
#  ('Tanpa', 'mekanisme'): 1,
#  ('mekanisme', 'seperti'): 3,
#  ('seperti', 'ini,'): 164,
#  ('ini,', 'kalaupun'): 1,
#  ('kalaupun', 'ada'): 4,
#  ('ada', 'satu'): 310,
#  ('satu', 'asam'): 1,
#  ('asam', 'amino'): 24,
#  ('amino', 'terbentuk,'): 1,
#  ('terbentuk,', 'ia'): 1,
#  ('ia', 'akan'): 434,
#  ('akan', 'segera'): 271,
#  ('segera', 'hancur.'): 1,
#  ('hancur.', '24'): 1,
#  ('24', '”'): 1,
#  ('”', '”Di'): 2,
#  ('”Di', 'sini'): 1,
#  ('sini', 'tidak'): 17,
#  ('tidak', 'ada'): 2500,
#  ('ada', 'dewa,'): 1,
#  ('dewa,', 'wahai'): 1,
#  ('wahai', 'Puteriku.'): 3,
#  ('Puteriku.', '25'): 1,
#  ('25', 'Tidak'): 1,
#  ('Tidak', 'hanya'): 104,
#  ('hanya', 'itu,'): 65,
#  ('itu,', 'Djusman'): 1,
#  ('Djusman', 'juga'): 1,
#  ('juga', 'menganggap'): 10,
#  ('menganggap', 'WC'): 2,
#  ('WC', 'umum'): 6,
#  ('umum', 'Terminal'): 1,
#  ('Terminal', 'Purabaya'): 5,
#  ('Purabaya', 'terharum.'): 1,
#  ('terharum.', '26'): 1,
#  ('26', 'Ketika'): 1,
#  ('Ketika', 'Anda'): 55,
#  ('Anda', 'menerima'): 7,
#  ('menerima', 'hal-hal'): 5,
#  ('hal-hal', 'yang'): 454,
#  ('yang', 'Anda'): 368,
#  ('Anda', 'inginkan,'): 9,
#  ('inginkan,', 'dan'): 9,
#  ('dan', 'merasakan'): 33,
#  ('merasakan', 'perasaan'): 5,
#  ('perasaan', 'syukur'): 1,
#  ('syukur', 'karena'): 5,
#  ('karena', 'menerimanya,'): 1,
#  ('menerimanya,', 'Anda'): 1,
#  ('Anda', 'dapat'): 228,
#  ('dapat', 'melepas'): 1,
#  ('melepas', 'dan'): 4,
#  ('dan', 'mengganti'): 12,
#  ('mengganti', 'gambar-gambar'): 1,
#  ('gambar-gambar', 'itu'): 1,
#  ('itu', 'dengan'): 430,
#  ('dengan', 'gambar'): 19,
#  ('gambar', 'baru.'): 1,
#  ('baru.', '27'): 1,
#  ('27', 'Saya'): 1,
#  ('Saya', 'minta'): 22,
#  ('minta', 'maaf,'): 24,
#  ('maaf,', 'kalau'): 2,
#  ('kalau', 'ada'): 182,
#  ('ada', 'kata-kata'): 12,
#  ('kata-kata', 'yang'): 123,
#  ('yang', 'tidak'): 3656,
#  ('tidak', 'berkenan,'): 2,
#  ('berkenan,', 'karena'): 1,
#  ('karena', 'keterbatasan'): 15,
#  ('keterbatasan', 'saya'): 2,
#  ('saya', 'dalam'): 34,
#  ('dalam', 'menyampaikan'): 22,
#  ('menyampaikan', 'pendapat.'): 2,
#  ('pendapat.', '28'): 1,
#  ('28', 'Kami'): 1,
#  ('Kami', 'mau'): 6,
#  ('mau', 'setia'): 4,
#  ('setia', 'kepada-Mu'): 1,
#  ('kepada-Mu', 'dalam'): 1,
#  ('dalam', 'hidup'): 237,
#  ('hidup', 'kami'): 4,
#  ('kami', 'ini'): 28,
#  ('ini', 'Tuhan.'): 2,
#  ('Tuhan.', '29'): 1,
#  ('29', 'Lelah'): 1,
#  ('Lelah', 'Kandang'): 1,
#  ('Kandang', 'Lelah'): 1,
#  ('Lelah', 'kandang'): 1,
#  ('kandang', '(disebut'): 1,
#  ('(disebut', 'juga'): 1,
#  ('juga', 'cage'): 1,
#  ('cage', 'layer'): 1,
#  ('layer', 'fatigue'): 1,
#  ('fatigue', 'atau'): 1,
#  ('atau', 'osteoporosis)'): 1,
#  ('osteoporosis)', 'sering'): 1,
#  ('sering', 'terjadi'): 66,
#  ('terjadi', 'pada'): 496,
#  ('pada', 'ayam'): 11,
#  ('ayam', 'telur'): 1,
#  ('telur', 'yang'): 16,
#  ('yang', 'dipelihara'): 2,
#  ('dipelihara', 'dalam'): 5,
#  ('dalam', 'kandang'): 4,
#  ('kandang', 'baterai.'): 1,
#  ('baterai.', '30'): 1,
#  ('30', 'Berarti'): 1,
#  ('Berarti', 'perubahan'): 1,
#  ('perubahan', 'fisik'): 3,
#  ('fisik', 'dari'): 13,
#  ('dari', 'kecil'): 13,
#  ('kecil', 'menjadi'): 8,
#  ('menjadi', 'besar,'): 7,
#  ('besar,', 'dari'): 3,
#  ('dari', 'kurus'): 1,
#  ('kurus', 'menjadi'): 1,
#  ('menjadi', 'gemuk,'): 2,
#  ('gemuk,', 'dan'): 2,
#  ('dan', 'pendek'): 5,
#  ('pendek', 'menjadi'): 2,
#  ('menjadi', 'semakin'): 219,
#  ('semakin', 'tinggi'): 29,
#  ('tinggi', 'bukanlah'): 2,
#  ('bukanlah', 'karena'): 6,
#  ('karena', 'proses'): 22,
#  ('proses', 'belajar,'): 7,
#  ('belajar,', 'dan'): 16,
#  ('dan', 'oleh'): 53,
#  ('oleh', 'karena'): 240,
#  ('karena', 'itu'): 663,
#  ('itu', 'tidak'): 1209,
#  ('tidak', 'dapat'): 1426,
#  ('dapat', 'disebut'): 38,
#  ('disebut', 'sebagai'): 282,
#  ('sebagai', 'proses'): 30,
#  ('proses', 'belajar.'): 15,
#  ('belajar.', '31'): 1,
#  ('31', 'Sebab,'): 1,
#  ('Sebab,', 'bagian'): 1,
#  ('bagian', 'selatan'): 30,
#  ('selatan', 'makam'): 1,
#  ('makam', 'yang'): 7,
#  ('yang', 'berjarak'): 31,
#  ('berjarak', '5'): 2,
#  ('5', 'meter'): 4,
#  ('meter', 'merupakan'): 1,
#  ('merupakan', 'areal'): 2,
#  ('areal', 'persawahan.'): 1,
#  ('persawahan.', '32'): 1,
#  ('32', 'Empat'): 1,
#  ('Empat', 'obat'): 1,
#  ('obat', 'kategori'): 1,
#  ('kategori', 'obat'): 1,
#  ('obat', 'lini'): 2,
#  ('lini', 'pertama'): 1,
#  ('pertama', 'adalah'): 132,
#  ('adalah', 'isoniazid,'): 1,
#  ('isoniazid,', 'rifampidin,'): 1,
#  ('rifampidin,', 'ethambutol,'): 1,
#  ('ethambutol,', 'dan'): 1,
#  ('dan', 'pyrazinamid.'): 1,
#  ('pyrazinamid.', '33'): 1,
#  ('33', 'Kini,'): 1,
#  ('Kini,', 'setelah'): 2,
#  ('setelah', 'tahu'): 10,
#  ('tahu', 'manfaat'): 1,
#  ('manfaat', 'lebih'): 5,
#  ('lebih', 'dan'): 28,
#  ('dan', 'terapi'): 7,
#  ('terapi', 'urin,'): 1,
#  ('urin,', 'Gunawan'): 1,
#  ('Gunawan', 'tak'): 2,
#  ('tak', 'takut-takut'): 1,
#  ('takut-takut', 'lagi'): 1,
#  ('lagi', 'untuk'): 129,
#  ('untuk', 'minum'): 15,
#  ('minum', 'air'): 37,
#  ('air', 'seni'): 8,
#  ('seni', 'sendiri.'): 1,
#  ('sendiri.', '34'): 1,
#  ('34', 'Ketahuilah'): 1,
#  ('Ketahuilah', 'bahwa'): 9,
#  ('bahwa', 'hal-hal'): 4,
#  ('hal-hal', 'ini'): 11,
#  ('ini', 'adalah'): 1420,
#  ('adalah', 'sumber'): 25,
#  ('sumber', 'atau'): 3,
#  ('atau', 'penyebab'): 3,
#  ('penyebab', 'berbagai'): 2,
#  ('bentuk', 'penderitaan.'): 1,
#  ('penderitaan.', '35'): 1,
#  ('35', 'Apakah'): 1,
#  ('Apakah', 'saat'): 4,
#  ('saat', 'ini'): 1415,
#  ('ini', 'aku'): 206,
#  ('aku', 'masih'): 143,
#  ('masih', 'Yahudi?'): 1,
#  ('Yahudi?', '36'): 1,
#  ('36', 'Nanti'): 1,
#  ('Nanti', 'urusan'): 1,
#  ('urusan', 'gaji'): 1,
#  ('gaji', 'BS'): 3,
#  ('BS', 'langsung'): 1,
#  ('langsung', 'sama'): 1,
#  ('sama', 'yayasan.'): 1,
#  ('yayasan.', '37'): 1,
#  ('37', 'Bruce'): 1,
#  ('Bruce', 'bekerja'): 1,
#  ('bekerja', 'di'): 292,
#  ('di', 'sebuah'): 489,
#  ('sebuah', 'stasiun'): 10,
#  ('stasiun', 'TV'): 19,
#  ('TV', 'Australia'): 1,
#  ('Australia', 'sebagai'): 3,
#  ('sebagai', 'kameramen'): 2,
#  ('kameramen', 'untuk'): 1,
#  ('untuk', 'reporter'): 2,
#  ('reporter', 'yang'): 5,
#  ('yang', 'ada'): 1922,
#  ('di', 'Jakarta.'): 180,
#  ('Jakarta.', '38'): 1,
#  ('38', 'Memang,'): 1,
#  ('Memang,', 'mereka'): 3,
#  ('mereka', 'menyangkal'): 2,
#  ('menyangkal', 'hak-hak'): 1,
#  ('hak-hak', 'mereka'): 2,
#  ('mereka', 'ketika'): 18,
#  ('ketika', 'datang.'): 1,
#  ('datang.', '39'): 1,
#  ('39', 'Dengan'): 1,
#  ('Dengan', 'merenungkan'): 1,
#  ('merenungkan', 'secara'): 1,
#  ('secara', 'khusuk'): 1,
#  ('khusuk', 'peristiwa-peristiwa'): 1,
#  ('peristiwa-peristiwa', 'Rosario,'): 1,
#  ('Rosario,', 'kita'): 1,
#  ('kita', 'dapat'): 327,
#  ('dapat', 'mencontoh'): 3,
#  ('mencontoh', 'teladan'): 1,
#  ('teladan', 'Maria'): 1,
#  ('Maria', 'yang'): 13,
#  ('yang', '“mendengarkan'): 1,
#  ('“mendengarkan', 'Sabda'): 1,
#  ('Sabda', 'Tuhan'): 2,
#  ('Tuhan', 'serta'): 3,
#  ('serta', 'menyimpannya'): 1,
#  ('menyimpannya', 'dalam'): 4,
#  ('dalam', 'hati”.'): 1,
#  ('hati”.', '40'): 1,
#  ('40', 'Kalau'): 1,
#  ('Kalau', 'petugas'): 1,
#  ('petugas', 'loket'): 3,
#  ('loket', 'tidak'): 1,
#  ('tidak', 'mengizinkan,'): 4,
#  ('mengizinkan,', 'boleh'): 1,
#  ('boleh', 'jadi'): 41,
#  ('jadi', 'harus'): 16,
#  ('harus', 'mencoba'): 8,
#  ('mencoba', 'lagi'): 5,
#  ('lagi', 'dan'): 120,
#  ('dan', 'kembali'): 150,
#  ('kembali', 'mengulang'): 2,
#  ('mengulang', 'rintangan'): 1,
#  ('rintangan', 'dari'): 3,
#  ('dari', 'gerbang'): 8,
#  ('gerbang', 'depan.'): 2,
#  ('depan.', '41'): 1,
#  ('41', 'Begitu'): 1,
#  ('Begitu', 'penjelasan'): 2,
#  ('penjelasan', 'Syaikh'): 2,
#  ('Syaikh', 'Ahmad'): 10,
#  ('Ahmad', 'waktu'): 2,
#  ('waktu', 'kutanyakan'): 2,
#  ('kutanyakan', 'ihwal'): 2,
#  ('ihwal', 'cara'): 2,
#  ('cara', 'aneh'): 2,
#  ('aneh', 'orang'): 3,
#  ('orang', 'Mesir'): 11,
#  ('Mesir', 'dalam'): 1,
#  ('dalam', 'meredam'): 1,
#  ('meredam', 'amarah.'): 1,
#  ('amarah.', '42'): 1,
#  ('42', 'Dengan'): 1,
#  ('Dengan', 'alasan'): 21,
#  ('alasan', 'yang'): 115,
#  ('yang', 'baik,'): 174,
#  ('baik,', 'diklaim'): 1,
#  ('diklaim', 'bahwa'): 2,
#  ('bahwa', 'hubungan'): 20,
#  ('hubungan', 'individual'): 2,
#  ('individual', 'antara'): 1,
#  ('antara', 'dokter-pasien'): 1,
#  ('dokter-pasien', 'merupakan'): 1,
#  ('merupakan', 'cara'): 29,
#  ('cara', 'terbaik'): 19,
#  ('terbaik', 'dalam'): 22,
#  ('dalam', 'mendapatkan'): 16,
#  ('mendapatkan', 'pengetahuan'): 9,
#  ('pengetahuan', 'tentang'): 62,
#  ('tentang', 'pasien'): 2,
#  ('pasien', 'dan'): 18,
#  ('dan', 'kelangsungan'): 5,
#  ('kelangsungan', 'perawatan'): 1,
#  ('perawatan', 'yang'): 25,
#  ('yang', 'optimal'): 20,
#  ('optimal', 'dalam'): 7,
#  ('dalam', 'mencegah'): 8,
#  ('mencegah', 'dan'): 9,
#  ('dan', 'menyembuhkan'): 9,
#  ('menyembuhkan', 'penyakit.'): 4,
#  ('penyakit.', '43'): 1,
#  ('43', 'Guardiola'): 1,
#  ('Guardiola', 'meminta'): 1,
#  ('meminta', 'maaf'): 58,
#  ('maaf', 'karena'): 37,
#  ('karena', 'telah'): 104,
#  ('telah', 'gagal'): 14,
#  ('gagal', 'untuk'): 20,
#  ('untuk', 'mempertahankan'): 95,
#  ('mempertahankan', 'gelar'): 2,
#  ('gelar', 'Piala'): 2,
#  ('Piala', 'Raja.'): 1,
#  ('Raja.', '44'): 1,
#  ('44', '"'): 1,
#  ('"', 'Yang'): 11,
#  ('Yang', 'manakah'): 3,
#  ('manakah', 'namanya'): 2,
#  ('namanya', 'benar'): 2,
#  ('benar', 'Tohukah'): 2,
#  ('Tohukah', 'atau'): 2,
#  ('atau', 'Toi.'): 1,
#  ('Toi.', '45'): 1,
#  ('45', 'Pengurus'): 1,
#  ('Pengurus', 'dan'): 2,
#  ('dan', 'installers'): 1,
#  ('installers', 'berhadapan'): 1,
#  ('berhadapan', 'dengan'): 179,
#  ('dengan', 'Bahkan'): 1,
#  ('Bahkan', 'para'): 15,
#  ('para', 'pemakai'): 9,
#  ('pemakai', 'wireless'): 1,
#  ('wireless', 'LAN'): 16,
#  ('LAN', 'sebab'): 1,
#  ('sebab', 'mereka'): 40,
#  ('mereka', 'sering'): 34,
#  ('sering', 'mengalami'): 17,
#  ('mengalami', 'permasalahan'): 3,
#  ('permasalahan', 'dengan'): 6,
#  ('dengan', 'multipath.'): 1,
#  ('multipath.', '46'): 1,
#  ('46', 'Sori'): 1,
#  ('Sori', 'nih'): 1,
#  ('nih', 'ya,'): 1,
#  ('ya,', 'kata2'): 1,
#  ('kata2', 'anda'): 2,
#  ('anda', 'ini'): 13,
#  ('ini', 'berbau'): 2,
#  ('berbau', 'khayalan'): 1,
#  ('khayalan', 'di'): 1,
#  ('di', 'mana'): 915,
#  ('mana', 'setelah'): 2,
#  ('setelah', 'Muhammad'): 4,
#  ('Muhammad', 'mati'): 1,
#  ('mati', 'terjadi'): 1,
#  ('terjadi', 'perpecahan'): 8,
#  ('perpecahan', 'pada'): 1,
#  ('pada', 'masyakat'): 1,
#  ('masyakat', 'muslim'): 1,
#  ('muslim', 'saat'): 1,
#  ('saat', 'itu.'): 183,
#  ('itu.', '47'): 1,
#  ('47', 'Simanjuntak,'): 1,
#  ('Simanjuntak,', 'Familia'): 1,
#  ('Familia', 'Novita'): 1,
#  ('Novita', '(2006)'): 1,
#  ('(2006)', 'Penerapan'): 10,
#  ('Penerapan', 'pertanian'): 2,
#  ('pertanian', 'organik'): 5,
#  ('organik', 'untuk'): 3,
#  ('untuk', 'mengendalikan'): 35,
#  ('mengendalikan', 'kualitas'): 1,
#  ('kualitas', 'kesuburan'): 1,
#  ('kesuburan', 'tanah'): 1,
#  ('tanah', 'dan'): 77,
#  ('menghasilkan', 'produk'): 13,
#  ('produk', 'pangan'): 8,
#  ('pangan', 'bebas'): 1,
#  ('bebas', 'pestisida'): 1,
#  ('pestisida', '(studi'): 1,
#  ('(studi', 'kasus'): 19,
#  ('kasus', 'pertanian'): 1,
#  ('organik', 'bina'): 1,
#  ('bina', 'sarana'): 1,
#  ('sarana', 'bhakti'): 1,
#  ('bhakti', 'Cisarua,'): 1,
#  ('Cisarua,', 'Bogor).'): 1,
#  ('Bogor).', '48'): 1,
#  ('48', 'Rusa-rusa'): 1,
#  ('Rusa-rusa', 'Palestina'): 1,
#  ('Palestina', 'kadang'): 1,
#  ('kadang', 'kala'): 21,
#  ('kala', 'menemukan'): 1,
#  ('menemukan', 'batang'): 1,
#  ('batang', 'sungai'): 3,
#  ('sungai', 'yang'): 67,
#  ('yang', 'kering'): 13,
#  ('kering', 'pada'): 4,
#  ('pada', 'musim'): 54,
#  ('musim', 'kemarau.'): 5,
#  ('kemarau.', '49'): 1,
#  ('49', 'Namun'): 1,
#  ('Namun', 'secara'): 12,
#  ('secara', 'prosentase'): 1,
#  ('prosentase', 'bisa'): 1,
#  ('bisa', 'jadi'): 296,
#  ('jadi', 'yang'): 22,
#  ('yang', 'akidahnya'): 1,
#  ('akidahnya', 'jelek'): 1,
#  ('jelek', 'itu'): 4,
#  ('itu', 'jumlahnya'): 4,
#  ('jumlahnya', 'terlalu'): 1,
#  ('terlalu', 'banyak.'): 12,
#  ('banyak.', '50'): 1,
#  ('50', 'Mungkin'): 1,
#  ('Mungkin', 'mobil'): 1,
#  ('mobil', 'itu'): 32,
#  ('itu', 'tak'): 276,
#  ('tak', 'akan'): 334,
#  ('akan', 'bisa'): 229,
#  ('bisa', 'diperbaiki'): 8,
#  ('diperbaiki', 'lagi.'): 3,
#  ('lagi.', '51'): 1,
#  ('51', 'Terutama'): 1,
#  ('Terutama', 'ketika'): 1,
#  ('ketika', 'mereka'): 154,
#  ('mereka', 'kabupaten'): 1,
#  ('kabupaten', 'telah'): 2,
#  ('telah', 'dirancang'): 9,
#  ('dirancang', 'program'): 2,
#  ('program', 'bimbingan'): 45,
#  ('bimbingan', 'dan'): 98,
#  ('dan', 'konseling'): 71,
#  ('konseling', 'hati-hati'): 1,
#  ('hati-hati', 'seperti'): 1,
#  ('seperti', 'busur'): 1,
#  ('busur', 'kami'): 1,
#  ('kami', 'menyarankan'): 4,
#  ('menyarankan', 'dan'): 1,
#  ('dan', 'telah'): 127,
#  ('telah', 'didefinisikan'): 3,
#  ('didefinisikan', 'dengan'): 4,
#  ('dengan', 'jelas'): 159,
#  ('jelas', 'sehingga'): 5,
#  ('sehingga', 'sifat'): 2,
#  ('sifat', 'Integra'): 1,
#  ('Integra', 'program'): 1,
#  ('program', 'mereka,'): 2,
#  ('mereka,', 'pertahanan'): 1,
#  ('pertahanan', 'program'): 1,
#  ('program', 'didukung'): 1,
#  ('didukung', 'partisipasi'): 1,
#  ('partisipasi', 'nyenyak.'): 1,
#  ('nyenyak.', '52'): 1,
#  ('52', 'Mereka'): 1,
#  ('Mereka', 'pun'): 60,
#  ('pun', 'makhluk'): 3,
#  ('makhluk', 'Allah,'): 2,
#  ('Allah,', 'yang'): 34,
#  ('yang', 'keberadaannya'): 8,
#  ('keberadaannya', 'tergantung'): 1,
#  ('tergantung', 'pada'): 235,
#  ('pada', 'Dia,'): 2,
#  ('Dia,', 'dan'): 6,
#  ('dan', 'akhirnya'): 255,
#  ('akhirnya', 'merupakan'): 3,
#  ('merupakan', 'pelayan'): 1,
#  ('pelayan', 'maksud-Nya.'): 1,
#  ('maksud-Nya.', '53'): 1,
#  ('53', 'Beberapa'): 1,
#  ('Beberapa', 'langkah'): 9,
#  ('langkah', 'ia'): 5,
#  ('ia', 'terdorong'): 4,
#  ('terdorong', 'ke'): 13,
#  ('ke', 'samping,'): 10,
#  ('samping,', 'namun'): 2,
#  ('namun', 'kemudian'): 27,
#  ('kemudian', 'tubuhnya'): 4,
#  ('tubuhnya', 'jatuh'): 2,
#  ('jatuh', 'terbanting'): 4,
#  ('terbanting', 'di'): 3,
#  ('di', 'tanah.'): 13,
#  ('tanah.', '54'): 1,
#  ('54', 'Apa'): 1,
#  ('Apa', 'yang'): 452,
#  ('yang', 'sudah'): 2172,
#  ('sudah', 'ada,'): 27,
#  ('ada,', 'pertahankan'): 1,
#  ('pertahankan', 'dan'): 3,
#  ('dan', 'jangan'): 78,
#  ('jangan', 'ditambahkan.'): 2,
#  ('ditambahkan.', '55'): 1,
#  ('55', 'Ia'): 1,
#  ('Ia', 'hanya'): 73,
#  ('hanya', 'memiliki'): 66,
#  ('memiliki', 'satu'): 42,
#  ('satu', 'ekor'): 6,
#  ('ekor', 'kuda'): 10,
#  ('kuda', 'betina.'): 1,
#  ('betina.', '56'): 1,
#  ('56', 'Keluar'): 1,
#  ('Keluar', 'pintu,'): 2,
#  ('pintu,', 'menuruni'): 2,
#  ('menuruni', 'tangga,'): 6,
#  ('tangga,', 'di'): 1,
#  ('di', 'pintu,'): 5,
#  ('tangga,', 'semua'): 1,
#  ('semua', 'jalan'): 5,
#  ('jalan', 'ke'): 51,
#  ('ke', 'sebelah'): 10,
#  ('sebelah', 'kanan'): 47,
#  ('kanan', 'Duncan.'): 1,
#  ('Duncan.', '57'): 1,
#  ('57', 'Podcast'): 1,
#  ('Podcast', 'makin'): 1,
#  ('makin', 'populer'): 4,
#  ('populer', 'dikalangan'): 1,
#  ('dikalangan', 'internet'): 1,
#  ('internet', 'marketer.'): 1,
#  ('marketer.', '58'): 1,
#  ('58', 'Dong'): 1,
#  ('Dong', 'Yi'): 59,
#  ('Yi', 'bingung,'): 1,
#  ('bingung,', 'apa'): 4,
#  ('apa', 'yang'): 3666,
#  ('harus', 'dilakukannya'): 10,
#  ('dilakukannya', 'sekarang.'): 1,
#  ('sekarang.', '59'): 1,
#  ('59', 'Bayangkan'): 1,
#  ('Bayangkan', 'negara'): 1,
#  ('negara', 'tetangga'): 19,
#  ('tetangga', 'aja'): 1,
#  ('aja', 'pakai'): 2,
#  ('pakai', 'perusahaan'): 1,
#  ('perusahaan', 'negara.'): 3,
#  ('negara.', '60'): 1,
#  ('60', 'Kalau'): 1,
#  ('Kalau', 'Yesus'): 12,
#  ('Yesus', 'memaksudkan'): 1,
#  ('memaksudkan', 'hidup'): 1,
#  ('hidup', 'rohani,'): 1,
#  ('rohani,', 'maka'): 4,
#  ('maka', 'jelaslah'): 1,
#  ('jelaslah', 'bahwa'): 22,
#  ('bahwa', 'kelimpahan'): 1,
#  ('kelimpahan', 'yang'): 3,
#  ('yang', 'Ia'): 26,
#  ('Ia', 'maksudkan,'): 1,
#  ('maksudkan,', 'juga'): 1,
#  ('juga', 'adalah'): 46,
#  ('adalah', 'kelimpahan'): 1,
#  ('kelimpahan', 'rohani!'): 1,
#  ('rohani!', '61'): 1,
#  ('61', 'Kerapatan'): 1,
#  ('Kerapatan', 'materinya'): 1,
#  ('materinya', 'tinggal'): 2,
#  ('tinggal', 'sepersepuluh'): 1,
#  ('sepersepuluh', 'kg'): 1,
#  ('kg', 'tiap'): 2,
#  ('tiap', 'liter.'): 2,
#  ('liter.', '62'): 1,
#  ('62', '"Nasib'): 1,
#  ('"Nasib', 'baik'): 1,
#  ('baik', 'Qel'): 1,
#  ('Qel', 'tak'): 3,
#  ('tak', 'terus'): 3,
#  ('terus', 'pergi'): 2,
#  ('pergi', 'Pudu'): 1,
#  ('Pudu', 'tadi.'): 1,
#  ('tadi.', '63'): 1,
#  ('63', 'Gue'): 1,
#  ('Gue', 'berakhir'): 1,
#  ('berakhir', 'dengan'): 72,
#  ('dengan', 'hepatitis'): 1,
#  ('hepatitis', 'dasyat'): 1,
#  ('dasyat', 'di'): 5,
#  ('di', 'rumah'): 694,
#  ('rumah', 'sakit.'): 82,
#  ('sakit.', '64'): 1,
#  ('64', 'Keempat'): 1,
#  ('Keempat', 'penyair'): 1,
#  ('penyair', 'itu'): 2,
#  ('itu', 'terhitung'): 4,
#  ('terhitung', 'paling'): 2,
#  ('paling', 'depan'): 14,
#  ('depan', 'menampilkan'): 1,
#  ('menampilkan', 'sajak-sajak'): 1,
#  ('sajak-sajak', 'yang'): 3,
#  ('yang', 'jernih'): 16,
#  ('jernih', 'dan'): 23,
#  ('dan', 'makin'): 29,
#  ('makin', 'jauh'): 5,
#  ('jauh', 'dari'): 498,
#  ('dari', 'hiruk-pikuk'): 2,
#  ('hiruk-pikuk', 'sosial'): 1,
#  ('sosial', 'dan'): 125,
#  ('dan', 'politik.'): 18,
#  ('politik.', '65'): 1,
#  ('65', 'Prioritas'): 1,
#  ('Prioritas', 'penting'): 1,
#  ('penting', 'dari'): 84,
#  ('dari', 'kemandirian'): 2,
#  ('kemandirian', 'energi'): 1,
#  ('energi', 'ini'): 7,
#  ('adalah', 'pemerataan'): 1,
#  ('pemerataan', 'dan'): 3,
#  ('dan', 'jaminan'): 17,
#  ('jaminan', 'ketersediaan'): 2,
#  ('ketersediaan', 'listrik'): 4,
#  ('listrik', 'bagi'): 3,
#  ('bagi', 'rakyat'): 26,
#  ('rakyat', 'dengan'): 10,
#  ('dengan', 'harga'): 224,
#  ('harga', 'yang'): 132,
#  ('yang', 'terjangkau.'): 7,
#  ('terjangkau.', '66'): 1,
#  ('66', 'Bila'): 1,
#  ('Bila', 'kita'): 57,
#  ('kita', 'tahu'): 97,
#  ('tahu', 'kematian'): 1,
#  ('kematian', 'begitu'): 1,
#  ('begitu', 'akrab—demikianlah'): 1,
#  ('akrab—demikianlah', 'pikir'): 1,
#  ('pikir', 'saya—manusia'): 1,
#  ('saya—manusia', 'akan'): 1,
#  ('akan', 'tahu'): 60,
#  ('tahu', 'bahwa'): 541,
#  ('bahwa', 'kelangkaan'): 1,
#  ('kelangkaan', 'dan'): 1,
#  ('dan', 'pengendalian'): 16,
#  ('pengendalian', 'hanyalah'): 1,
#  ('hanyalah', 'satu'): 5,
#  ('satu', 'bagian'): 54,
#  ('bagian', 'dari'): 685,
#  ('dari', 'peradaban:'): 1,
#  ('peradaban:', 'bagian'): 1,
#  ('bagian', 'yang'): 230,
#  ('yang', 'lupa,'): 1,
#  ('lupa,', 'bahwa'): 11,
#  ('bahwa', 'kita'): 279,
#  ('kita', 'bukan'): 25,
#  ('bukan', 'hanya'): 425,
#  ('hanya', 'makhluk'): 1,
#  ('makhluk', 'yang'): 90,
#  ('yang', 'menyadari'): 26,
#  ('menyadari', 'potensi,'): 1,
#  ('potensi,', 'tapi'): 1,
#  ('tapi', 'juga'): 280,
#  ('juga', 'impotensi'): 1,
#  ('impotensi', 'diri.'): 1,
#  ('diri.', '67'): 1,
#  ('67', 'Tapi'): 1,
#  ('Tapi', 'yang'): 103,
#  ('yang', 'keren'): 2,
#  ('keren', 'lho,”'): 1,
#  ('lho,”', 'kata'): 1,
#  ('kata', 'Ika'): 1,
#  ('Ika', 'dengan'): 1,
#  ('dengan', 'suara'): 219,
#  ('suara', 'yang'): 156,
#  ('yang', 'amat'): 243,
#  ('amat', 'manja.'): 1,
#  ('manja.', '68'): 1,
#  ('68', '”'): 1,
#  ('”', 'Kata'): 86,
#  ('Kata', 'Polisi'): 1,
#  ('Polisi', 'Berkumis,'): 1,
#  ('Berkumis,', 'mendengar'): 1,
#  ('mendengar', 'itu'): 5,
#  ('itu', 'Feli'): 1,
#  ('Feli', 'berhenti'): 1,
#  ('berhenti', 'menari'): 1,
#  ('menari', 'seolah'): 1,
#  ('seolah', 'menolaknya.'): 1,
#  ('menolaknya.', '69'): 1,
#  ...}

# %%
# Bigram model
def P_bi(word, N=sum(COUNT_PAIRS.values())):
  sum = 0
  for pair_key in COUNT_PAIRS.keys():
    if word in pair_key:
      sum += COUNT_PAIRS[pair_key]
  return sum/N

# %% [markdown]
# We can see that there are 432,184 distinct words, which together appear 4,902,106 times, with 'yang' being the most common word, appearing 151,796 times (or a probability of about 3% using the unigram model and about 6% using the bigram model) and other words being less probable:

# %%
len(WORDS)
# Out:
# 432184

# %%
sum(WORDS.values())
# Out:
# 4902106

# %%
WORDS.most_common(10)
# Out:
# [('yang', 151796),
#  ('dan', 109411),
#  ('di', 70168),
#  ('dengan', 54857),
#  ('itu', 51588),
#  ('ini', 44693),
#  ('tidak', 43062),
#  ('untuk', 42823),
#  ('dari', 41478),
#  ('dalam', 39131)]

# %%
print("Max P_uni:", max(WORDS, key = P_uni))
# print("Max P_bi:", max(WORDS, key = P_bi))
# Out:
# Max P_uni: yang

# %%
print("P_uni:", P_uni('yang'))
print("P_bi:", P_bi('yang'))
# Out:
# P_uni: 0.0309654666790151
# P_bi: 0.06171189462504349

# %%
print("P_uni:", P_uni('konjungsi'))
print("P_bi:", P_bi('konjungsi'))
# Out:
# P_uni: 6.119818706490639e-07
# P_bi: 4.152020414653975e-07

# %%
print("P_uni:", P_uni('sanubari'))
print("P_bi:", P_bi('sanubari'))
# Out:
# P_uni: 2.4479274825962556e-06
# P_bi: 3.32161633172318e-06

# %% [markdown]
# 4. **Error Model**: We can make candidates(word) produce the first non-empty list of candidates in order of priority:
#
# > The original word, if it is known; otherwise
#
# > The list of known words at edit distance one away, if there are any; otherwise
#
# > The list of known words at edit distance two away, if there are any; otherwise
#
# > The original word, even though it is not known.
#
# Then we don't need to multiply by a P(w|c) factor, because every candidate at the chosen priority will have the same probability (according to our flawed model). That gives us:

# %%
def correction_uni(word): 
  return max(candidates(word), key = P_uni)

def correction_bi(word): 
  return max(candidates(word), key = P_bi)

def candidates(word): 
    return known([word]) or known(edits1(word)) or known(edits2(word)) or [word]

# %% [markdown]
# The function correction(word) returns a likely spelling correction:

# %%
print(candidates('analosis'))
print("Unigram:", correction_uni('analosis'))
print("Bigram:", correction_bi('analosis'))
# Out:
# {'analsis', 'analisis', 'analysis', 'analogis'}
# Unigram: analisis
# Bigram: analisis

# %%
print(candidates('silakn'))
print("Unigram:", correction_uni('silakn'))
print("Bigram:", correction_bi('silakn'))
# Out:
# {'silakan', 'silaen'}
# Unigram: silakan
# Bigram: silakan

# %% [markdown]
# ## **Evaluation**

# %%
def spelltest(tests, model, verbose = True):
    "Run correction(wrong) on all (right, wrong) pairs; report results."
    import time
    start = time.clock()
    good, unknown = 0, 0
    n = len(tests)
    for right, wrong in tests:
        if model == 'uni':
          w = correction_uni(wrong)
        elif model == 'bi':
          w = correction_bi(wrong)
        good += (w == right)
        if w != right:
            unknown += (right not in WORDS)
            if verbose:
                print('correction({}) => {} ({}); expected {} ({})'
                      .format(wrong, w, WORDS[w], right, WORDS[right]))
    dt = time.clock() - start
    print('{:.0%} of {} correct ({:.0%} unknown) at {:.0f} words per second '
          .format(good / n, n, unknown / n, n / dt))
    
def Testset(lines):
    "Parse 'right: wrong1 wrong2' lines into [('right', 'wrong1'), ('right', 'wrong2')] pairs."
    return [(right, wrong)
            for (right, wrongs) in (line.split(':') for line in lines)
            for wrong in wrongs.split()]

# %%
# Unigram model test
spelltest(Testset(open('/content/drive/MyDrive/Colab Data/Spelling Corrector/error.txt')), 'uni')
# Out:
# correction(smeua) => smeua (1); expected ﻿semua (0)
# correction(smua) => smua (22); expected ﻿semua (0)
# correction(seuma) => semua (7573); expected ﻿semua (0)
# correction(klas) => klas (25); expected kelas (1265)
# correction(kela) => kela (1); expected kelas (1265)
# correction(gaung) => gaung (8); expected gabung (23)
# correction(gabun) => gaun (73); expected gabung (23)
# correction(gbung) => bung (343); expected gabung (23)
# correction(sekrang) => sekrang (5); expected sekarang (4690)
# correction(skarang) => skarang (5); expected sekarang (4690)
# correction(sekaran) => sekaran (1); expected sekarang (4690)
# correction(seger) => seger (4); expected segar (266)
# correction(sega) => sega (3); expected segar (266)
# correction(sgar) => agar (4599); expected segar (266)
# correction(untu) => untu (11); expected untuk (42823)
# correction(utnuk) => utnuk (14); expected untuk (42823)
# correction(tulikan) => tulisan (981); expected tuliskan (50)
# correction(kerana) => kerana (34); expected karena (21065)
# correction(karna) => karna (56); expected karena (21065)
# correction(karen) => karen (18); expected karena (21065)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   after removing the cwd from sys.path.
# correction(perajurit) => perajurit (19); expected prajurit (619)
# correction(pirarti) => piranti (34); expected prajurit (619)
# correction(maslaha) => maslah (6); expected masalah (3138)
# correction(malsahs) => malah (1026); expected masalah (3138)
# correction(bearti) => bearti (4); expected berarti (2524)
# correction(beariti) => bearti (4); expected berarti (2524)
# correction(alaan) => alasan (1274); expected jalan (4627)
# correction(ari) => ari (126); expected air (3336)
# correction(baijr) => banjr (1); expected banjir (314)
# correction(bantun) => bantun (1); expected bantuan (912)
# correction(teapi) => teapi (3); expected tetapi (7326)
# correction(ttpi) => tapi (10855); expected tetapi (7326)
# correction(tapi) => tapi (10855); expected tetapi (7326)
# correction(mdh) => sdh (59); expected mudah (1649)
# correction(maduh) => madun (234); expected mudah (1649)
# correction(tulung) => tulung (6); expected tolong (327)
# correction(tulong) => tulong (1); expected tolong (327)
# correction(hajun) => harun (60); expected hujan (647)
# correction(hin) => in (910); expected hujan (647)
# correction(hujuan) => tujuan (1878); expected hujan (647)
# correction(ipi) => ipi (1); expected api (798)
# correction(iap) => ia (18552); expected api (798)
# correction(kalang) => kalang (11); expected kalung (32)
# correction(kaung) => kang (669); expected kalung (32)
# correction(kalng) => kang (669); expected kalung (32)
# correction(narka) => nara (32); expected neraka (303)
# correction(naraka) => naraka (1); expected neraka (303)
# correction(nrka) => nerka (5); expected neraka (303)
# correction(mrka) => maka (7412); expected mereka (24021)
# correction(maraka) => malaka (133); expected mereka (24021)
# correction(mreka) => mreka (11); expected mereka (24021)
# correction(reksaya) => raksasa (246); expected rekayasa (130)
# correction(halp) => hal (10628); expected halo (15)
# correction(hallo) => hallo (8); expected halo (15)
# correction(hao) => hal (10628); expected halo (15)
# correction(nereka) => nereka (3); expected mereka (24021)
# correction(mrk) => mrk (34); expected mereka (24021)
# correction(mrka) => maka (7412); expected mereka (24021)
# correction(tok) => tok (42); expected tidak (43062)
# correction(sesuatau) => sesuatau (2); expected sesuatu (2310)
# correction(swt) => swt (294); expected sesuatu (2310)
# correction(gil) => gil (42); expected gila (423)
# correction(limba) => lima (1191); expected lomba (213)
# correction(loba) => loba (7); expected lomba (213)
# correction(loma) => lama (3281); expected lomba (213)
# correction(krk) => krk (1); expected korek (24)
# correction(korex) => korea (236); expected korek (24)
# correction(hny) => hny (1); expected hanya (10789)
# correction(hnya) => hnya (1); expected hanya (10789)
# correction(hannya) => hannya (2); expected hanya (10789)
# correction(munim) => munim (1); expected minum (568)
# correction(mnm) => mem (100); expected minum (568)
# correction(jwab) => jwab (1); expected jawab (1649)
# correction(jwb) => jwb (1); expected jawab (1649)
# correction(stu) => stu (1); expected satu (10288)
# correction(sau) => sau (1); expected satu (10288)
# correction(atu) => atu (7); expected satu (10288)
# correction(dwa) => dia (17568); expected dua (5595)
# correction(wa) => wa (193); expected dua (5595)
# correction(ga) => ga (430); expected tiga (2691)
# correction(lina) => lina (20); expected lima (1191)
# correction(loma) => lama (3281); expected lima (1191)
# correction(nam) => nam (120); expected enam (577)
# correction(tuju) => tuju (20); expected tujuh (485)
# correction(tumuh) => tubuh (2218); expected tujuh (485)
# correction(lapan) => lapan (8); expected delapan (414)
# correction(spuluh) => puluh (487); expected sepuluh (392)
# correction(bg) => bg (8); expected bagi (6637)
# correction(bgii) => bii (17); expected bagi (6637)
# correction(bag) => bag (23); expected bagi (6637)
# correction(sdh) => sdh (59); expected sudah (15882)
# correction(sudh) => sudh (1); expected sudah (15882)
# correction(yg) => yg (3029); expected yang (151796)
# correction(yng) => yng (25); expected yang (151796)
# correction(ygn) => yg (3029); expected yang (151796)
# correction(sy) => sy (57); expected saya (21188)
# correction(sya) => sya (23); expected saya (21188)
# correction(aya) => aya (7); expected saya (21188)
# correction(dsn) => dsn (2); expected dan (109411)
# correction(and) => and (425); expected dan (109411)
# correction(dna) => dna (136); expected dan (109411)
# correction(akna) => akna (1); expected akan (27115)
# correction(akn) => akn (7); expected akan (27115)
# correction(anka) => anka (1); expected akan (27115)
# correction(sdr) => sdr (26); expected saudara (1129)
# correction(liat) => liat (120); expected lihat (997)
# correction(liay) => liar (242); expected lihat (997)
# correction(tanyak) => tanyak (1); expected tanya (915)
# correction(tny) => tny (2); expected tanya (915)
# correction(jadual) => jadual (4); expected jadwal (254)
# correction(kmu) => kmu (3); expected kamu (2987)
# correction(akmu) => akmu (2); expected kamu (2987)
# correction(da) => da (152); expected dia (17568)
# correction(ida) => ida (48); expected dia (17568)
# correction(kai) => kai (30); expected kami (8038)
# correction(kalan) => kalau (8400); expected kalian (1991)
# correction(ak) => ak (16); expected aku (14370)
# correction(kua) => kua (16); expected aku (14370)
# correction(menjdi) => menjdi (2); expected menjadi (14912)
# correction(orng) => orng (8); expected orang (26627)
# correction(roang) => roang (1); expected orang (26627)
# correction(kya) => kya (3); expected kaya (601)
# correction(kaaya) => karya (1264); expected kaya (601)
# correction(takta) => fakta (641); expected takhta (13)
# correction(tahta) => tahta (70); expected takhta (13)
# correction(penteng) => penting (2601); expected benteng (274)
# correction(draring) => drawing (2); expected daring (1)
# correction(darink) => drink (13); expected daring (1)
# correction(darring) => darling (4); expected daring (1)
# correction(izni) => ini (44693); expected izin (408)
# 46% of 240 correct (1% unknown) at 170 words per second
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
# Bigram model test
spelltest(Testset(open('/content/drive/MyDrive/Colab Data/Spelling Corrector/error.txt')), 'bi')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   after removing the cwd from sys.path.
# correction(smeua) => smeua (1); expected ﻿semua (0)
# correction(smua) => smua (22); expected ﻿semua (0)
# correction(seuma) => semua (7573); expected ﻿semua (0)
# correction(klas) => klas (25); expected kelas (1265)
# correction(kela) => kela (1); expected kelas (1265)
# correction(gaung) => gaung (8); expected gabung (23)
# correction(gabun) => gaun (73); expected gabung (23)
# correction(sekrang) => sekrang (5); expected sekarang (4690)
# correction(skarang) => skarang (5); expected sekarang (4690)
# correction(sekaran) => sekaran (1); expected sekarang (4690)
# correction(seger) => seger (4); expected segar (266)
# correction(sega) => sega (3); expected segar (266)
# correction(sgar) => agar (4599); expected segar (266)
# correction(untu) => untu (11); expected untuk (42823)
# correction(utnuk) => utnuk (14); expected untuk (42823)
# correction(tulikan) => tulisan (981); expected tuliskan (50)
# correction(kerana) => kerana (34); expected karena (21065)
# correction(karna) => karna (56); expected karena (21065)
# correction(karen) => karen (18); expected karena (21065)
# correction(perajurit) => perajurit (19); expected prajurit (619)
# correction(pirarti) => piranti (34); expected prajurit (619)
# correction(maslaha) => maslah (6); expected masalah (3138)
# correction(malsahs) => malah (1026); expected masalah (3138)
# correction(bearti) => bearti (4); expected berarti (2524)
# correction(beariti) => bearti (4); expected berarti (2524)
# correction(alaan) => alasan (1274); expected jalan (4627)
# correction(ari) => ari (126); expected air (3336)
# correction(baijr) => banjr (1); expected banjir (314)
# correction(bantun) => bantun (1); expected bantuan (912)
# correction(teapi) => teapi (3); expected tetapi (7326)
# correction(ttpi) => tapi (10855); expected tetapi (7326)
# correction(tapi) => tapi (10855); expected tetapi (7326)
# correction(mdh) => sdh (59); expected mudah (1649)
# correction(maduh) => madu (101); expected mudah (1649)
# correction(tulung) => tulung (6); expected tolong (327)
# correction(tulong) => tulong (1); expected tolong (327)
# correction(hajun) => ajun (3); expected hujan (647)
# correction(hin) => bin (659); expected hujan (647)
# correction(hujuan) => tujuan (1878); expected hujan (647)
# correction(ipi) => ipi (1); expected api (798)
# correction(iap) => ia (18552); expected api (798)
# correction(kalang) => kalang (11); expected kalung (32)
# correction(kaung) => kang (669); expected kalung (32)
# correction(kalng) => kang (669); expected kalung (32)
# correction(narka) => nara (32); expected neraka (303)
# correction(naraka) => naraka (1); expected neraka (303)
# correction(nrka) => nerka (5); expected neraka (303)
# correction(mrka) => maka (7412); expected mereka (24021)
# correction(maraka) => marak (43); expected mereka (24021)
# correction(mreka) => mreka (11); expected mereka (24021)
# correction(reksaya) => raksasa (246); expected rekayasa (130)
# correction(halp) => hal (10628); expected halo (15)
# correction(hallo) => hallo (8); expected halo (15)
# correction(hao) => hal (10628); expected halo (15)
# correction(nereka) => nereka (3); expected mereka (24021)
# correction(mrk) => mrk (34); expected mereka (24021)
# correction(mrka) => maka (7412); expected mereka (24021)
# correction(tok) => tok (42); expected tidak (43062)
# correction(sesuatau) => sesuatau (2); expected sesuatu (2310)
# correction(swt) => swt (294); expected sesuatu (2310)
# correction(gil) => gil (42); expected gila (423)
# correction(limba) => lima (1191); expected lomba (213)
# correction(loba) => loba (7); expected lomba (213)
# correction(loma) => lama (3281); expected lomba (213)
# correction(krk) => krk (1); expected korek (24)
# correction(hny) => hny (1); expected hanya (10789)
# correction(hnya) => hnya (1); expected hanya (10789)
# correction(hannya) => hannya (2); expected hanya (10789)
# correction(munim) => munim (1); expected minum (568)
# correction(mnm) => mem (100); expected minum (568)
# correction(jwab) => jwab (1); expected jawab (1649)
# correction(jwb) => jwb (1); expected jawab (1649)
# correction(stu) => stu (1); expected satu (10288)
# correction(sau) => sau (1); expected satu (10288)
# correction(atu) => atu (7); expected satu (10288)
# correction(dwa) => dia (17568); expected dua (5595)
# correction(wa) => wa (193); expected dua (5595)
# correction(ga) => ga (430); expected tiga (2691)
# correction(lina) => lina (20); expected lima (1191)
# correction(loma) => lama (3281); expected lima (1191)
# correction(nam) => nam (120); expected enam (577)
# correction(tuju) => tuju (20); expected tujuh (485)
# correction(tumuh) => tubuh (2218); expected tujuh (485)
# correction(lapan) => lapan (8); expected delapan (414)
# correction(senblan) => senilai (187); expected sembilan (208)
# correction(spuluh) => puluh (487); expected sepuluh (392)
# correction(bg) => bg (8); expected bagi (6637)
# correction(bgii) => bgai (1); expected bagi (6637)
# correction(bag) => bag (23); expected bagi (6637)
# correction(sdh) => sdh (59); expected sudah (15882)
# correction(sudh) => sudh (1); expected sudah (15882)
# correction(yg) => yg (3029); expected yang (151796)
# correction(yng) => yng (25); expected yang (151796)
# correction(ygn) => yg (3029); expected yang (151796)
# correction(sy) => sy (57); expected saya (21188)
# correction(sya) => sya (23); expected saya (21188)
# correction(aya) => aya (7); expected saya (21188)
# correction(dsn) => dsn (2); expected dan (109411)
# correction(and) => and (425); expected dan (109411)
# correction(dna) => dna (136); expected dan (109411)
# correction(akna) => akna (1); expected akan (27115)
# correction(akn) => akn (7); expected akan (27115)
# correction(anka) => anka (1); expected akan (27115)
# correction(sadara) => sadar (1082); expected saudara (1129)
# correction(sdr) => sdr (26); expected saudara (1129)
# correction(liat) => liat (120); expected lihat (997)
# correction(liay) => liar (242); expected lihat (997)
# correction(tanyak) => tanyak (1); expected tanya (915)
# correction(tny) => tny (2); expected tanya (915)
# correction(jadual) => jadual (4); expected jadwal (254)
# correction(kmu) => kmu (3); expected kamu (2987)
# correction(akmu) => akmu (2); expected kamu (2987)
# correction(da) => da (152); expected dia (17568)
# correction(ida) => ida (48); expected dia (17568)
# correction(kai) => kai (30); expected kami (8038)
# correction(kalan) => kalau (8400); expected kalian (1991)
# correction(ak) => ak (16); expected aku (14370)
# correction(kua) => kua (16); expected aku (14370)
# correction(menjdi) => menjdi (2); expected menjadi (14912)
# correction(orng) => orng (8); expected orang (26627)
# correction(roang) => roang (1); expected orang (26627)
# correction(kya) => kya (3); expected kaya (601)
# correction(kaaya) => karya (1264); expected kaya (601)
# correction(takta) => tata (508); expected takhta (13)
# correction(tahta) => tahta (70); expected takhta (13)
# correction(penteng) => penting (2601); expected benteng (274)
# correction(draring) => drawing (2); expected daring (1)
# correction(darink) => drink (13); expected daring (1)
# correction(darring) => jarring (2); expected daring (1)
# correction(izni) => ini (44693); expected izin (408)
# 46% of 240 correct (1% unknown) at 1 words per second
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %% [markdown]
# ## **Analysis**
#
# From the evaluation above, we can see that both models have the same accuracy of 46% from 240 entries. Both models also have the same unknown words percentage of 1%. The differentiating factor thus lie in the processing speed of the models, where the unigram model is worlds faster with speed of 170 words/sec compared to the bigram model's mere 1 word/sec. Therefore we can conclude that for this use case, the unigram model is the better option, since it yields the same accuracy as the bigram model but at a much faster processing speed.
#
# One problem worth noting for this assignment is that it seems that the corpus dataset contains non-baku Bahasa Indonesia words such as 'analisa' and 'jadual', English words such as 'drink' and 'drawing', as well as non-words such as 'banjr' and 'hannya'. This causes the model to yield undesired outputs. For example if the input is 'jadual', we expect the correction to be 'jadwal', but the output correction is still 'jadual' because indeed there is the word 'jadual' in the corpus and thus the model interpret the word to be already correct since it is in the corpus and made no further correction. A similar case also applies when the input word is 'darring'. We expect the correction to be 'daring' as in the abbreviation of 'dalam jaringan' or 'online', but the output correction is 'jarring' instead, an English word meaning 'incongruous in a striking or shocking way; clashing'. This occured because there are English words in our corpus, which there shouldn't be, and thus 'jarring' was prioritized more than 'daring', which is the correct output.
#
# Also a minor problem is that the student-submitted error dataset contains error words that are actually correct words and are in the corpus, for instance 'dna' (as in the chemical molecule deoxyribonucleic acid) and 'gaung' (meaning echo in English). Those words were meant to be the misspelled form of 'dan' and 'gabung' respectively, but the student who submitted those words perhaps unknowingly wrote actual correct words. This also resulted in the models yielding an 'undesired' output as when we input the word 'dna' and 'gaung', it doesn't correct to 'dan' and 'gabung' because the former words are actually correct words that are in the corpus.
#
# An explanation on how the unigram model is better than the bigram model might boil down to data sparsity: As our n-gram length increases, the amount of times we will see any given n-gram will decrease: In the most extreme example, if we have a corpus where the maximum document length is n tokens and you are looking for an m-gram where m=n+1, we will, of course, have no data points at all because it's simply not possible to have a sequence of that length in your data set. The more sparse your data set, the worse you can model it. For this reason, despite that a higher-order n-gram model, in theory, contains more information about a word's context, it cannot easily generalize to other data sets (known as overfitting) because the number of events (i.e. n-grams) it has seen during training becomes progressively less as n increases. On the other hand, a lower-order model lacks contextual information and so may underfit our data.
#
# For this reason, if we have a very relatively large amount of token types (i.e. the vocabulary of your text is very rich) but each of these types has a very low frequency, we may get better results with a lower-order n-gram model. Similarly, if our training data set is very small, we may do better with a lower-order n-gram model. However, assuming that we have enough data to avoid over-fitting, we then get better separability of our data with a higher-order model.
#
# Usually, n-grams more than one is better as it carries more information about the context in general. However, sometimes unigrams are also calculated besides bigram and trigrams and used as fallback for them. This is also useful if you want a higher recall than precision to search unigrams. For instance, we are searching for all possible uses of verb "make".
#
# Lets use statistical machine translation as an example: intuitively, the best scenario is that our model has seen the full sentence (lets say 6-grams) before and knows its translation as a whole. If this is not the case we try to divide it to smaller n-grams, keeping into consideration that the more information we know about the word surroundings, the better the translation. For example, if we want to translate "Tom Green" to German, if we have seen the bi-gram we will know it is a person name and should remain as it is but if our model never saw it, you would fall back to unigrams and translate "Tom" and "Green" separately. Thus "Green" will be translated as a color to "Grün" and so on.
#
# Also, in search knowing more about the surrounding context makes the results more accurate.
